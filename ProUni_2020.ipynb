# %% [markdown]
# # Bolsas concedidas e perfil dos beneficiários do ProUni - 2020

# %% [markdown]
# https://dados.gov.br/dados/conjuntos-dados/mec-prouni
#
# https://dadosabertos.mec.gov.br/prouni/item/124-bolsas-e-perfil-2020
#
# O Programa Universidade para Todos - Prouni tem como finalidade a concessão de bolsas de estudo integrais e parciais em cursos de graduação e sequenciais de formação específica, em instituições de ensino superior privadas que oferece, em contrapartida, isenção de tributos àquelas instituições que aderem ao Programa

# %% [markdown]
# ## Bibliotecas

# %%
# !pip install -U plotly
# !pip install --upgrade gdown -q
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (26.0)
# Downloading plotly-6.5.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 33.1 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.5.2

# %%
import os
import gdown
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import os
from datetime import datetime, date, time, timezone

# %%
# Caminho dos dados
'https://dadosabertos.mec.gov.br/images/conteudo/prouni/2020/ProuniRelatorioDadosAbertos2020.csv'
# Out:
# 'https://dadosabertos.mec.gov.br/images/conteudo/prouni/2020/ProuniRelatorioDadosAbertos2020.csv'

# %% [markdown]
# ## Disponibilizando a base

# %%
arquivo_id = '1cLDzDZphm6Uhrg6qnIY0wXPHF5cGYfgr'
url_drive = f'https://drive.google.com/uc?id={arquivo_id}'
nome_arquivo = 'ProuniRelatorioDadosAbertos2020.csv'

# Download do arquivo se ele não existir
if not os.path.exists(nome_arquivo):
    print("Baixando base de dados do ProUni...")
    gdown.download(url_drive, nome_arquivo, quiet=False)
else:
    print("Base de dados já disponível no ambiente.")


# Carregando o DataFrame
prouni_2020_inicial = pd.read_csv(nome_arquivo, encoding='LATIN-1', sep=';')

print(f"O dataset possui {prouni_2020_inicial.shape[0]} linhas.")
# Out:
# Baixando base de dados do ProUni...
# Downloading...
# From: https://drive.google.com/uc?id=1cLDzDZphm6Uhrg6qnIY0wXPHF5cGYfgr
# To: /content/ProuniRelatorioDadosAbertos2020.csv
# 100%|██████████| 29.9M/29.9M [00:00<00:00, 66.9MB/s]
# O dataset possui 166830 linhas.

# %% [markdown]
# ## Explorando a base

# %% [markdown]
# ### Características da base

# %%
prouni_2020_inicial.shape
# Out:
# (166830, 17)

# %%
# Código do e-MEC referente a IES que concedeu a bolsa ProUni

prouni_2020_inicial['CODIGO_EMEC_IES_BOLSA'].unique().shape
# Out:
# (1333,)

# %%
# Nome/Razão Social da Instituição de Ensino Superior que concedeu a bolsa ProUni

prouni_2020_inicial['NOME_IES_BOLSA'].unique().shape
# Out:
# (1376,)

# %%
prouni_2020_inicial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166830 entries, 0 to 166829
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ANO_CONCESSAO_BOLSA             166830 non-null  int64
#  1   CODIGO_EMEC_IES_BOLSA           166830 non-null  int64
#  2   NOME_IES_BOLSA                  166830 non-null  object
#  3   MUNICIPIO                       166830 non-null  object
#  4   CAMPUS                          166830 non-null  object
#  5   TIPO_BOLSA                      166830 non-null  object
#  6   MODALIDADE_ENSINO_BOLSA         166830 non-null  object
#  7   NOME_CURSO_BOLSA                166792 non-null  object
#  8   NOME_TURNO_CURSO_BOLSA          166830 non-null  object
#  9   CPF_BENEFICIARIO                166830 non-null  object
#  10  SEXO_BENEFICIARIO               166830 non-null  object
#  11  RACA_BENEFICIARIO               166830 non-null  object
#  12  DATA_NASCIMENTO                 166830 non-null  object
#  13  BENEFICIARIO_DEFICIENTE_FISICO  166830 non-null  object
#  14  REGIAO_BENEFICIARIO             166830 non-null  object
#  15  UF_BENEFICIARIO                 166830 non-null  object
#  16  MUNICIPIO_BENEFICIARIO          166830 non-null  object
# dtypes: int64(2), object(15)
# memory usage: 21.6+ MB

# %%
# Verificando se há null

prouni_2020_inicial.isnull().sum()
# Out:
# ANO_CONCESSAO_BOLSA                0
# CODIGO_EMEC_IES_BOLSA              0
# NOME_IES_BOLSA                     0
# MUNICIPIO                          0
# CAMPUS                             0
# TIPO_BOLSA                         0
# MODALIDADE_ENSINO_BOLSA            0
# NOME_CURSO_BOLSA                  38
# NOME_TURNO_CURSO_BOLSA             0
# CPF_BENEFICIARIO                   0
# SEXO_BENEFICIARIO                  0
# RACA_BENEFICIARIO                  0
# DATA_NASCIMENTO                    0
# BENEFICIARIO_DEFICIENTE_FISICO     0
# REGIAO_BENEFICIARIO                0
# UF_BENEFICIARIO                    0
# MUNICIPIO_BENEFICIARIO             0
# dtype: int64

# %% [markdown]
# ### Tratamento de NULL

# %%
prouni_2020_inicial['NOME_CURSO_BOLSA'].count()
# Out:
# np.int64(166792)

# %%
# Identificando quantidade de valores null da coluna

prouni_2020_inicial['NOME_CURSO_BOLSA'].isnull().sum()
# Out:
# np.int64(38)

# %%
prouni_2020_inicial[prouni_2020_inicial['NOME_CURSO_BOLSA'].isnull()]
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 166273                 2020                   1270
# 166274                 2020                     14
# 166353                 2020                    519
# 166405                 2020                    137
# 166406                 2020                   4915
# 166407                 2020                    457
# 166420                 2020                    434
# 166421                 2020                    163
# 166472                 2020                   1414
# 166491                 2020                   2835
# 166526                 2020                    316
# 166527                 2020                    316
# 166528                 2020                     21
# 166532                 2020                     22
# 166540                 2020                   1414
# 166541                 2020                   1414
# 166542                 2020                   1422
# 166557                 2020                     13
# 166573                 2020                    823
# 166615                 2020                    271
# 166629                 2020                   1558
# 166666                 2020                    450
# 166667                 2020                     13
# 166668                 2020                    316
# 166674                 2020                    374
# 166692                 2020                   5591
# 166693                 2020                    298
# 166694                 2020                    163
# 166717                 2020                    298
# 166738                 2020                   2756
# 166739                 2020                   1986
# 166740                 2020                    163
# 166780                 2020                    163
# 166789                 2020                   5544
# 166790                 2020                    353
# 166791                 2020                    353
# 166794                 2020                   5544
# 166820                 2020                    757
#
#                                            NOME_IES_BOLSA  \
# 166273     CENTRO UNIVERSITÁRIO ESTÁCIO DE RIBEIRÃO PRETO
# 166274              UNIVERSIDADE DO VALE DO RIO DOS SINOS
# 166353                  UNIVERSIDADE CATÓLICA DO SALVADOR
# 166405               CENTRO UNIVERSITÁRIO SAGRADO CORAÇÃO
# 166406                     FACULDADE ESTÁCIO DE CASTANHAL
# 166407               UNIVERSIDADE ANHANGUERA DE SÃO PAULO
# 166420                          FACULDADE SANTA MARCELINA
# 166421                         UNIVERSIDADE ESTÁCIO DE SÁ
# 166472                     CENTRO UNIVERSITÁRIO SÃO LUCAS
# 166491            CENTRO UNIVERSITÁRIO MAURÍCIO DE NASSAU
# 166526                         UNIVERSIDADE NOVE DE JULHO
# 166527                         UNIVERSIDADE NOVE DE JULHO
# 166528  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO RIO GRANDE...
# 166532               UNIVERSIDADE PRESBITERIANA MACKENZIE
# 166540                     CENTRO UNIVERSITÁRIO SÃO LUCAS
# 166541                     CENTRO UNIVERSITÁRIO SÃO LUCAS
# 166542                      CENTRO UNIVERSITÁRIO DO NORTE
# 166557                      UNIVERSIDADE DE CAXIAS DO SUL
# 166573                                 UNIVERSIDADE CEUMA
# 166615                     UNIVERSIDADE DO OESTE PAULISTA
# 166629                 FACULDADE DOCTUM DE JOÃO MONLEVADE
# 166666           CENTRO UNIVERSITÁRIO SÃO LUCAS JI-PARANÁ
# 166667                      UNIVERSIDADE DE CAXIAS DO SUL
# 166668                         UNIVERSIDADE NOVE DE JULHO
# 166674  CENTRO UNIVERSITÁRIO DAS FACULDADES METROPOLIT...
# 166692                       FACULDADES INTEGRADAS CAMÕES
# 166693                      UNIVERSIDADE PITÁGORAS UNOPAR
# 166694                         UNIVERSIDADE ESTÁCIO DE SÁ
# 166717                      UNIVERSIDADE PITÁGORAS UNOPAR
# 166738                 FACULDADE ANHANGUERA DE VALPARAÍSO
# 166739  CENTRO UNIVERSITÁRIO ESTÁCIO JUIZ DE FORA - ES...
# 166740                         UNIVERSIDADE ESTÁCIO DE SÁ
# 166780                         UNIVERSIDADE ESTÁCIO DE SÁ
# 166789                FACULDADE PRESIDENTE ANTÔNIO CARLOS
# 166790           FACULDADE EVANGELICA MACKENZIE DO PARANÁ
# 166791           FACULDADE EVANGELICA MACKENZIE DO PARANÁ
# 166794                FACULDADE PRESIDENTE ANTÔNIO CARLOS
# 166820                   CENTRO UNIVERSITÁRIO DA AMAZÔNIA
#
#                    MUNICIPIO  \
# 166273                ITAJAI
# 166274         CAXIAS DO SUL
# 166353              SALVADOR
# 166405                 BAURU
# 166406             CASTANHAL
# 166407             SAO PAULO
# 166420             SAO PAULO
# 166421        RIO DE JANEIRO
# 166472           PORTO VELHO
# 166491                RECIFE
# 166526             SAO PAULO
# 166527             SAO PAULO
# 166528          PORTO ALEGRE
# 166532             SAO PAULO
# 166540           PORTO VELHO
# 166541           PORTO VELHO
# 166542                MANAUS
# 166557         CAXIAS DO SUL
# 166573            IMPERATRIZ
# 166615               GUARUJA
# 166629        JOAO MONLEVADE
# 166666             JI-PARANA
# 166667         CAXIAS DO SUL
# 166668             SAO PAULO
# 166674             SAO PAULO
# 166692              CURITIBA
# 166693                   UBA
# 166694        RIO DE JANEIRO
# 166717             GUARAPARI
# 166738   VALPARAISO DE GOIAS
# 166739          JUIZ DE FORA
# 166740  SAO JOSE DOS PINHAIS
# 166780               NITEROI
# 166789        PORTO NACIONAL
# 166790              CURITIBA
# 166791              CURITIBA
# 166794        PORTO NACIONAL
# 166820              SANTAREM
#
#                                                    CAMPUS TIPO_BOLSA  \
# 166273                                    EAD ITAJAÍ - SC   INTEGRAL
# 166274                        POLO UNISINOS CAXIAS DO SUL   INTEGRAL
# 166353                                 CAMPUS - FEDERAÇÃO   INTEGRAL
# 166405                     CAMPUS - BAURU - JARDIM BRASIL   INTEGRAL
# 166406                                          CASTANHAL   INTEGRAL
# 166407                                     SAO PAULO (CL)   INTEGRAL
# 166420                                   UNIDADE ITAQUERA   INTEGRAL
# 166421                                EAD BONSUCESSO - RJ   INTEGRAL
# 166472                                           CAMPUS 1    PARCIAL
# 166491                                   UNINASSAU - SEDE   INTEGRAL
# 166526                             UNIDADE VERGUEIRO SEDE   INTEGRAL
# 166527                                      VILA PRUDENTE   INTEGRAL
# 166528                             CENTRAL - PORTO ALEGRE   INTEGRAL
# 166532                   CAMPUS  - SÃO PAULO - CONSOLAÇÃO   INTEGRAL
# 166540                      CAMPUS  - PORTO VELHO - AREAL    PARCIAL
# 166541                      CAMPUS  - PORTO VELHO - AREAL    PARCIAL
# 166542                            UNIDADE DE ENSINO PLAZA   INTEGRAL
# 166557                                        CAMPUS SEDE    PARCIAL
# 166573  UNIVERSIDADE DO CEUMA - UNICEUMA - CAMPUS IMPE...    PARCIAL
# 166615                                            GUARUJÁ   INTEGRAL
# 166629                                       UNIDADE SEDE   INTEGRAL
# 166666                                       UNIDADE SEDE   INTEGRAL
# 166667                                        CAMPUS SEDE   INTEGRAL
# 166668                                         VILA MARIA   INTEGRAL
# 166674             FMU - BRIGADEIRO - PREDIOS 32/39/43/44   INTEGRAL
# 166692                                             MERCÊS   INTEGRAL
# 166693                                  UBA/MG - I(8548)U   INTEGRAL
# 166694                                         JOÃO UCHOA   INTEGRAL
# 166717                         GUARAPARI/ES - I(1059479)U   INTEGRAL
# 166738      FACULDADE ANHANGUERA DE VALPARAÍSO - QUADRA 5   INTEGRAL
# 166739                                         RIO BRANCO   INTEGRAL
# 166740                      EAD SÃO JOSÉ DOS PINHAIS - PR   INTEGRAL
# 166780                                        NITERÓI III   INTEGRAL
# 166789                             ITPAC - PORTO NACIONAL   INTEGRAL
# 166790                                       UNIDADE SEDE   INTEGRAL
# 166791                                       UNIDADE SEDE   INTEGRAL
# 166794                             ITPAC - PORTO NACIONAL   INTEGRAL
# 166820                                       UNIDADE SEDE   INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 166273                     EAD              NaN      CURSO A DISTÂNCIA
# 166274                     EAD              NaN      CURSO A DISTÂNCIA
# 166353              PRESENCIAL              NaN               MATUTINO
# 166405              PRESENCIAL              NaN                NOTURNO
# 166406              PRESENCIAL              NaN                NOTURNO
# 166407              PRESENCIAL              NaN               MATUTINO
# 166420              PRESENCIAL              NaN               INTEGRAL
# 166421                     EAD              NaN      CURSO A DISTÂNCIA
# 166472              PRESENCIAL              NaN               INTEGRAL
# 166491              PRESENCIAL              NaN               MATUTINO
# 166526              PRESENCIAL              NaN             VESPERTINO
# 166527              PRESENCIAL              NaN                NOTURNO
# 166528              PRESENCIAL              NaN               MATUTINO
# 166532              PRESENCIAL              NaN               MATUTINO
# 166540              PRESENCIAL              NaN               INTEGRAL
# 166541              PRESENCIAL              NaN               INTEGRAL
# 166542              PRESENCIAL              NaN                NOTURNO
# 166557              PRESENCIAL              NaN                NOTURNO
# 166573              PRESENCIAL              NaN               INTEGRAL
# 166615              PRESENCIAL              NaN               INTEGRAL
# 166629              PRESENCIAL              NaN                NOTURNO
# 166666              PRESENCIAL              NaN                NOTURNO
# 166667              PRESENCIAL              NaN               INTEGRAL
# 166668              PRESENCIAL              NaN               MATUTINO
# 166674              PRESENCIAL              NaN                NOTURNO
# 166692              PRESENCIAL              NaN                NOTURNO
# 166693                     EAD              NaN      CURSO A DISTÂNCIA
# 166694              PRESENCIAL              NaN               MATUTINO
# 166717                     EAD              NaN      CURSO A DISTÂNCIA
# 166738              PRESENCIAL              NaN                NOTURNO
# 166739              PRESENCIAL              NaN               INTEGRAL
# 166740                     EAD              NaN      CURSO A DISTÂNCIA
# 166780              PRESENCIAL              NaN                NOTURNO
# 166789              PRESENCIAL              NaN               INTEGRAL
# 166790              PRESENCIAL              NaN               INTEGRAL
# 166791              PRESENCIAL              NaN               INTEGRAL
# 166794              PRESENCIAL              NaN               INTEGRAL
# 166820              PRESENCIAL              NaN               MATUTINO
#
#        CPF_BENEFICIARIO SEXO_BENEFICIARIO RACA_BENEFICIARIO DATA_NASCIMENTO  \
# 166273   106.XXX.XXX-77                 F            Branca      01/06/1998
# 166274   868.XXX.XXX-53                 M             Parda      07/07/1983
# 166353   075.XXX.XXX-12                 F     Não Informada      12/06/1999
# 166405   465.XXX.XXX-85                 M            Branca      17/11/2000
# 166406   053.XXX.XXX-46                 M     Não Informada      13/09/2001
# 166407   424.XXX.XXX-35                 F            Branca      28/12/1996
# 166420   122.XXX.XXX-06                 M            Branca      27/01/2000
# 166421   118.XXX.XXX-33                 M             Preta      02/10/1996
# 166472   147.XXX.XXX-90                 F             Parda      18/01/1995
# 166491   131.XXX.XXX-59                 M             Parda      09/11/2000
# 166526   421.XXX.XXX-84                 M            Branca      19/02/2001
# 166527   090.XXX.XXX-13                 M            Branca      14/10/2001
# 166528   038.XXX.XXX-01                 F            Branca      17/04/1997
# 166532   442.XXX.XXX-02                 M            Branca      08/06/1999
# 166540   985.XXX.XXX-87                 F             Parda      17/02/1994
# 166541   083.XXX.XXX-48                 M             Parda      18/08/2000
# 166542   018.XXX.XXX-56                 F     Não Informada      10/05/1997
# 166557   033.XXX.XXX-00                 M            Branca      16/05/2001
# 166573   066.XXX.XXX-40                 M             Parda      06/03/1997
# 166615   363.XXX.XXX-08                 F            Branca      02/07/2002
# 166629   159.XXX.XXX-70                 M            Branca      13/07/2001
# 166666   050.XXX.XXX-16                 F             Parda      03/12/2001
# 166667   043.XXX.XXX-96                 M            Branca      17/02/1999
# 166668   478.XXX.XXX-08                 F            Branca      09/04/2000
# 166674   511.XXX.XXX-20                 M            Branca      10/03/2002
# 166692   104.XXX.XXX-33                 F            Branca      04/02/2000
# 166693   136.XXX.XXX-64                 F            Branca      29/12/1999
# 166694   151.XXX.XXX-76                 M             Preta      03/03/1995
# 166717   151.XXX.XXX-99                 F             Parda      23/10/2019
# 166738   072.XXX.XXX-86                 F     Não Informada      06/10/1998
# 166739   121.XXX.XXX-10                 M             Parda      03/05/2002
# 166740   071.XXX.XXX-75                 M            Branca      02/09/1993
# 166780   105.XXX.XXX-97                 F     Não Informada      17/11/1984
# 166789   013.XXX.XXX-25                 F            Branca      09/11/2002
# 166790   089.XXX.XXX-66                 F            Branca      10/06/1998
# 166791   100.XXX.XXX-51                 F            Branca      11/05/1999
# 166794   013.XXX.XXX-40                 F            Branca      20/11/1999
# 166820   040.XXX.XXX-35                 F             Parda      27/09/2002
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO  \
# 166273                              N                 SUL              SC
# 166274                              N                 SUL              RS
# 166353                              N            NORDESTE              BA
# 166405                              N             SUDESTE              SP
# 166406                              N               NORTE              PA
# 166407                              N             SUDESTE              SP
# 166420                              N             SUDESTE              MG
# 166421                              N             SUDESTE              RJ
# 166472                              N               NORTE              PA
# 166491                              N            NORDESTE              PE
# 166526                              N            NORDESTE              BA
# 166527                              N             SUDESTE              SP
# 166528                              N                 SUL              RS
# 166532                              N             SUDESTE              SP
# 166540                              N               NORTE              RO
# 166541                              N            NORDESTE              BA
# 166542                              N               NORTE              AM
# 166557                              N                 SUL              RS
# 166573                              N            NORDESTE              CE
# 166615                              N             SUDESTE              SP
# 166629                              N             SUDESTE              MG
# 166666                              N               NORTE              RO
# 166667                              N                 SUL              RS
# 166668                              N             SUDESTE              SP
# 166674                              N             SUDESTE              SP
# 166692                              N                 SUL              PR
# 166693                              N             SUDESTE              MG
# 166694                              N             SUDESTE              RJ
# 166717                              N             SUDESTE              ES
# 166738                              N        CENTRO-OESTE              GO
# 166739                              N             SUDESTE              MG
# 166740                              N                 SUL              PR
# 166780                              N             SUDESTE              RJ
# 166789                              N            NORDESTE              MA
# 166790                              N                 SUL              PR
# 166791                              N            NORDESTE              PE
# 166794                              N            NORDESTE              MA
# 166820                              N               NORTE              PA
#
#          MUNICIPIO_BENEFICIARIO
# 166273                   ITAJAI
# 166274            CAXIAS DO SUL
# 166353             SIMOES FILHO
# 166405                  IACANGA
# 166406               ABAETETUBA
# 166407          TABOAO DA SERRA
# 166420            PARA DE MINAS
# 166421           RIO DE JANEIRO
# 166472                   MARABA
# 166491  JABOATAO DOS GUARARAPES
# 166526                 MACAUBAS
# 166527                SAO PAULO
# 166528             PORTO ALEGRE
# 166532                SAO PAULO
# 166540              PORTO VELHO
# 166541                   JEQUIE
# 166542                   MANAUS
# 166557          FLORES DA CUNHA
# 166573                      IPU
# 166615              CARAPICUIBA
# 166629           JOAO MONLEVADE
# 166666                JI-PARANA
# 166667              CHARQUEADAS
# 166668                  ITAPEVI
# 166674                SAO PAULO
# 166692                PIRAQUARA
# 166693                      UBA
# 166694           RIO DE JANEIRO
# 166717                GUARAPARI
# 166738                 LUZIANIA
# 166739                      UBA
# 166740                     LAPA
# 166780                  NITEROI
# 166789               ACAILANDIA
# 166790              CAMPO LARGO
# 166791                 PAULISTA
# 166794              JOAO LISBOA
# 166820                 SANTAREM

# %%
# Identificando quantidade única de Cursos ofertados

prouni_2020_inicial['NOME_CURSO_BOLSA'].nunique()
# Out:
# 317

# %%
# Excluindo os null

prouni_2020_inicial.dropna(subset=['NOME_CURSO_BOLSA'], inplace=True)

# %%
prouni_2020_inicial.isnull().sum()
# Out:
# ANO_CONCESSAO_BOLSA               0
# CODIGO_EMEC_IES_BOLSA             0
# NOME_IES_BOLSA                    0
# MUNICIPIO                         0
# CAMPUS                            0
# TIPO_BOLSA                        0
# MODALIDADE_ENSINO_BOLSA           0
# NOME_CURSO_BOLSA                  0
# NOME_TURNO_CURSO_BOLSA            0
# CPF_BENEFICIARIO                  0
# SEXO_BENEFICIARIO                 0
# RACA_BENEFICIARIO                 0
# DATA_NASCIMENTO                   0
# BENEFICIARIO_DEFICIENTE_FISICO    0
# REGIAO_BENEFICIARIO               0
# UF_BENEFICIARIO                   0
# MUNICIPIO_BENEFICIARIO            0
# dtype: int64

# %% [markdown]
# ### Tratamento de datas

# %%
prouni_2020_inicial['DATA_NASCIMENTO'] = pd.to_datetime(prouni_2020_inicial['DATA_NASCIMENTO'], format='%d/%m/%Y')
prouni_2020_inicial['DATA_NASCIMENTO']
# Out:
# 0        1973-08-11
# 1        1987-05-13
# 2        2001-07-23
# 3        2003-04-04
# 4        1977-12-07
#             ...
# 166825   1996-11-30
# 166826   2002-03-25
# 166827   1997-04-19
# 166828   1975-09-17
# 166829   1996-06-25
# Name: DATA_NASCIMENTO, Length: 166792, dtype: datetime64[ns]

# %% [markdown]
# ### Cálculo da Idade das pessoas beneficiárias

# %% [markdown]
# Ano de 2020 como referência

# %%
def calc_idade(nasc):
    ref_idade = datetime(year=2020, month=12, day=31)
    return ref_idade.year - nasc.year - ((ref_idade.month, ref_idade.day) < (nasc.month, nasc.day))  # verificando se a pessoa já fez aniversário

prouni_2020_inicial['IDADE'] = prouni_2020_inicial['DATA_NASCIMENTO'].apply(calc_idade)

# %%
prouni_2020_inicial[['DATA_NASCIMENTO', 'IDADE']].head(3)
# Out:
#   DATA_NASCIMENTO  IDADE
# 0      1973-08-11     47
# 1      1987-05-13     33
# 2      2001-07-23     19

# %%
prouni_2020_inicial.head(3)
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA              NOME_IES_BOLSA  \
# 0                 2020                    322       UNIVERSIDADE PAULISTA
# 1                 2020                    163  UNIVERSIDADE ESTÁCIO DE SÁ
# 2                 2020                  17670   FACULDADE DE QUIXERAMOBIM
#
#       MUNICIPIO                            CAMPUS TIPO_BOLSA  \
# 0      IPATINGA                          IPATINGA   INTEGRAL
# 1     FORTALEZA               EAD VIA CORPVS - CE   INTEGRAL
# 2  QUIXERAMOBIM  FACULDADE DE QUIXERAMOBIM - UNIQ   INTEGRAL
#
#   MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 0                     EAD        PEDAGOGIA      CURSO A DISTÂNCIA
# 1                     EAD        MARKETING      CURSO A DISTÂNCIA
# 2              PRESENCIAL         FARMÁCIA                NOTURNO
#
#   CPF_BENEFICIARIO SEXO_BENEFICIARIO RACA_BENEFICIARIO DATA_NASCIMENTO  \
# 0   991.XXX.XXX-91                 F             Parda      1973-08-11
# 1   067.XXX.XXX-01                 M             Parda      1987-05-13
# 2   623.XXX.XXX-27                 M             Parda      2001-07-23
#
#   BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO  \
# 0                              N             SUDESTE              MG
# 1                              N            NORDESTE              CE
# 2                              N            NORDESTE              CE
#
#   MUNICIPIO_BENEFICIARIO  IDADE
# 0   GOVERNADOR VALADARES     47
# 1              FORTALEZA     33
# 2                MOMBACA     19

# %% [markdown]
# ### Retirando da base pessoas com menos que 15 anos

# %% [markdown]
# `Quantidade de pessoas com até 15 anos de idade: 09`
#
# Podem ser inconsistências na base, pois a maioria dessa quantidade (66%) desta faixa nasceu no mesmo ano da concessão da bolsa

# %%
prouni_2020_inicial.groupby('IDADE').agg({'IDADE':'count'})
# Out:
#        IDADE
# IDADE
# 0          6
# 3          1
# 8          1
# 11         1
# 16         9
# ...      ...
# 68         1
# 70         2
# 73         2
# 74         2
# 91         1
#
# [61 rows x 1 columns]

# %%
prouni_2020 = prouni_2020_inicial[prouni_2020_inicial['IDADE'] >= 15].copy()
prouni_2020.head(3)
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA              NOME_IES_BOLSA  \
# 0                 2020                    322       UNIVERSIDADE PAULISTA
# 1                 2020                    163  UNIVERSIDADE ESTÁCIO DE SÁ
# 2                 2020                  17670   FACULDADE DE QUIXERAMOBIM
#
#       MUNICIPIO                            CAMPUS TIPO_BOLSA  \
# 0      IPATINGA                          IPATINGA   INTEGRAL
# 1     FORTALEZA               EAD VIA CORPVS - CE   INTEGRAL
# 2  QUIXERAMOBIM  FACULDADE DE QUIXERAMOBIM - UNIQ   INTEGRAL
#
#   MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 0                     EAD        PEDAGOGIA      CURSO A DISTÂNCIA
# 1                     EAD        MARKETING      CURSO A DISTÂNCIA
# 2              PRESENCIAL         FARMÁCIA                NOTURNO
#
#   CPF_BENEFICIARIO SEXO_BENEFICIARIO RACA_BENEFICIARIO DATA_NASCIMENTO  \
# 0   991.XXX.XXX-91                 F             Parda      1973-08-11
# 1   067.XXX.XXX-01                 M             Parda      1987-05-13
# 2   623.XXX.XXX-27                 M             Parda      2001-07-23
#
#   BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO  \
# 0                              N             SUDESTE              MG
# 1                              N            NORDESTE              CE
# 2                              N            NORDESTE              CE
#
#   MUNICIPIO_BENEFICIARIO  IDADE
# 0   GOVERNADOR VALADARES     47
# 1              FORTALEZA     33
# 2                MOMBACA     19

# %%
prouni_2020.groupby('IDADE').agg({'IDADE':'count'})
# Out:
#        IDADE
# IDADE
# 16         9
# 17      1043
# 18     28102
# 19     32992
# 20     21323
# 21     15024
# 22     10542
# 23      8631
# 24      6937
# 25      5883
# 26      4704
# 27      3902
# 28      3226
# 29      2710
# 30      2341
# 31      2111
# 32      1983
# 33      1640
# 34      1519
# 35      1353
# 36      1182
# 37      1153
# 38      1054
# 39       932
# 40       812
# 41       713
# 42       644
# 43       526
# 44       509
# 45       431
# 46       388
# 47       322
# 48       275
# 49       267
# 50       232
# 51       549
# 52       176
# 53       134
# 54       108
# 55        81
# 56        66
# 57        55
# 58        43
# 59        39
# 60        21
# 61        24
# 62        24
# 63        17
# 64        10
# 65         5
# 66         4
# 67         4
# 68         1
# 70         2
# 73         2
# 74         2
# 91         1

# %%
prouni_2020.shape
# Out:
# (166783, 18)

# %% [markdown]
# ### Definindo Faixas de Idade

# %%
bins = [15, 20, 30, 40, 50, 100]
labels = ['01. Entre 15 e 20', '02. Entre 21 e 30', '03. Entre 31 e 40', '04. Entre 41 e 50', '05. Acima de 50']

prouni_2020['FAIXA_ETARIA'] = pd.cut(prouni_2020['IDADE'], bins=bins, labels=labels, include_lowest=True)
prouni_2020[['IDADE', 'FAIXA_ETARIA', 'DATA_NASCIMENTO']].sort_values(by = 'IDADE', ascending=False).head(3)
# Out:
#         IDADE     FAIXA_ETARIA DATA_NASCIMENTO
# 59617      91  05. Acima de 50      1929-11-19
# 151927     74  05. Acima de 50      1946-04-02
# 51649      74  05. Acima de 50      1946-09-14

# %%
prouni_2020.shape
# Out:
# (166783, 19)

# %% [markdown]
# ### Padronizando nomes dos Cursos

# %%
prouni_2020['NOME_CURSO_BOLSA'].nunique()
# Out:
# 317

# %%
prouni_2020['NOME_CURSO_BOLSA'].sort_values().unique()
# Out:
# array(['ACUPUNTURA', 'ADMINISTRAÇÃO', 'ADMINISTRAÇÃO DE EMPRESAS',
#        'ADMINISTRAÇÃO PÚBLICA', 'AGRONEGÓCIO', 'AGRONOMIA',
#        'AGROPECUÁRIA', 'ANÁLISE DE DADOS',
#        'ANÁLISE E DESENVOLVIMENTO DE SISTEMAS',
#        'ANÁLISE E DESENVOLVIMENTO DE SISTEMAS INTERNET', 'AQUICULTURA',
#        'ARQUEOLOGIA', 'ARQUITETURA E URBANISMO',
#        'ARTE: HISTÓRIA, CRÍTICA E CURADORIA', 'ARTES', 'ARTES CÊNICAS',
#        'ARTES E MÍDIAS DIGITAIS', 'ARTES VISUAIS', 'AUDIOVISUAL',
#        'AUTOMAÇÃO INDUSTRIAL', 'AVIAÇÃO CIVIL', 'BANCO DE DADOS',
#        'BIBLIOTECONOMIA', 'BIG DATA E INTELIGÊNCIA ANALÍTICA',
#        'BIG DATA E INTELIGÊNCIA ARTIFICIAL', 'BIOCOMBUSTÍVEIS',
#        'BIOLOGIA', 'BIOMEDICINA', 'BIOTECNOLOGIA', 'CAFEICULTURA',
#        'CINEMA E AUDIOVISUAL', 'CIÊNCIA DA COMPUTAÇÃO',
#        'CIÊNCIA DE DADOS', 'CIÊNCIA DE DADOS E INTELIGÊNCIA ARTIFICIAL',
#        'CIÊNCIA ECONÔMICA', 'CIÊNCIA POLÍTICA', 'CIÊNCIAS AERONÁUTICAS',
#        'CIÊNCIAS AMBIENTAIS', 'CIÊNCIAS ATUARIAIS', 'CIÊNCIAS BIOLÓGICAS',
#        'CIÊNCIAS BIOLÓGICAS - MODALIDADE MEDICA', 'CIÊNCIAS CONTÁBEIS',
#        'CIÊNCIAS DA COMPUTAÇÃO', 'CIÊNCIAS DA RELIGIÇO',
#        'CIÊNCIAS DA RELIGIÇO - ENSINO RELIGIOSO', 'CIÊNCIAS ECONÔMICAS',
#        'CIÊNCIAS SOCIAIS', 'CIÊNCIAS SOCIOAMBIENTAIS', 'COACHING',
#        'COACHING E DESENVOLVIMENTO HUMANO', 'COMPUTAÇÃO',
#        'COMPUTAÇÃO GRÁFICA', 'COMUNICAÇÃO DAS ARTES DO CORPO',
#        'COMUNICAÇÃO E MARKETING', 'COMUNICAÇÃO E MULTIMEIOS',
#        'COMUNICAÇÃO INSTITUCIONAL', 'COMUNICAÇÃO SOCIAL',
#        'COMUNICAÇÃO SOCIAL - CINEMA',
#        'COMUNICAÇÃO SOCIAL - CINEMA E AUDIOVISUAL',
#        'COMUNICAÇÃO SOCIAL - CINEMA E MÍDIAS DIGITAIS',
#        'COMUNICAÇÃO SOCIAL - COMUNICAÇÃO DIGITAL',
#        'COMUNICAÇÃO SOCIAL - HABILITAÇÃO REALIZAÇÃO AUDIOVISUAL',
#        'COMUNICAÇÃO SOCIAL - JORNALISMO',
#        'COMUNICAÇÃO SOCIAL - PRODUÇÃO EDITORIAL',
#        'COMUNICAÇÃO SOCIAL - PUBLICIDADE E PROPAGANDA',
#        'COMUNICAÇÃO SOCIAL - RADIO E TELEVISÃO',
#        'COMUNICAÇÃO SOCIAL - RELAÇÕES PÚBLICAS', 'COMÉRCIO EXTERIOR',
#        'COMÉRCIO INTERNACIONAL', 'CONSTRUÇÃO DE EDIFÍCIOS',
#        'COZINHA CONTEMPORÃNEA', 'CRIAÇÃO DIGITAL', 'CRIMINOLOGIA',
#        'DANÇA', 'DEFESA CIBERNETICA', 'DESENHO INDUSTRIAL',
#        'DESENVOLVIMENTO DE SISTEMAS', 'DESIGN', 'DESIGN DE ANIMAÇÃO',
#        'DESIGN DE GAMES', 'DESIGN DE INTERIORES', 'DESIGN DE MODA',
#        'DESIGN DE PRODUTO', 'DESIGN DIGITAL', 'DESIGN GRÁFICO',
#        'DESIGN VISUAL', 'DIREITO', 'EDUCADOR SOCIAL',
#        'EDUCAÇÃO ARTÍSTICA', 'EDUCAÇÃO ARTÍSTICA - MÚSICA',
#        'EDUCAÇÃO ESPECIAL', 'EDUCAÇÃO FÍSICA',
#        'ELETRAMAZÔNIANICA INDUSTRIAL', 'EMBELEZAMENTO E IMAGEM PESSOAL',
#        'EMPREENDEDORISMO', 'ENFERMAGEM', 'ENGENHARIA',
#        'ENGENHARIA AERONÁUTICA', 'ENGENHARIA AERONÁUTICA E ESPAÇO',
#        'ENGENHARIA AGRONÔMICA', 'ENGENHARIA AGRÍCOLA E AMBIENTAL',
#        'ENGENHARIA AMBIENTAL',
#        'ENGENHARIA AMBIENTAL E ENERGIAS RENOVÁVEIS',
#        'ENGENHARIA AMBIENTAL E SANITÁRIA', 'ENGENHARIA AUTOMOTIVA',
#        'ENGENHARIA BIOMEDICA', 'ENGENHARIA CARTOGRÁFICA E DE AGRIMENSURA',
#        'ENGENHARIA CIVIL', 'ENGENHARIA CIVIL E AMBIENTAL',
#        'ENGENHARIA DA COMPUTAÇÃO', 'ENGENHARIA DE AGRONEGÓCIOS',
#        'ENGENHARIA DE ALIMENTOS', 'ENGENHARIA DE AUTOMAÇÃO E CONTROLE',
#        'ENGENHARIA DE BIOPROCESSOS E BIOTECNOLOGIA',
#        'ENGENHARIA DE COMPUTAÇÃO', 'ENGENHARIA DE CONTROLE E AUTOMAÇÃO',
#        'ENGENHARIA DE ENERGIA', 'ENGENHARIA DE ENERGIAS',
#        'ENGENHARIA DE MATERIAIS', 'ENGENHARIA DE MINAS',
#        'ENGENHARIA DE PESCA', 'ENGENHARIA DE PETRÓLEO',
#        'ENGENHARIA DE PETRÓLEO E GÁS', 'ENGENHARIA DE PRODUÇÃO',
#        'ENGENHARIA DE PRODUÇÃO MECÂNICA', 'ENGENHARIA DE ROBAMAZÔNIAS',
#        'ENGENHARIA DE SOFTWARE', 'ENGENHARIA ELETRAMAZÔNIANICA',
#        'ENGENHARIA ELETRAMAZÔNIANICA E DE TELECOMUNICAÇÕES',
#        'ENGENHARIA ELÉTRICA', 'ENGENHARIA FLORESTAL',
#        'ENGENHARIA INDUSTRIAL MECÂNICA', 'ENGENHARIA MECATRÔNICA',
#        'ENGENHARIA MECÂNICA', 'ENGENHARIA QUÍMICA', 'ESCRITA CRIATIVA',
#        'ESTATÍSTICA', 'ESTETICA', 'ESTETICA E COSMETOLOGIA',
#        'ESTETICA E IMAGEM PESSOAL', 'ESTÉTICA E COSMÉTICA', 'EVENTOS',
#        'FABRICAÇÃO MECÂNICA', 'FARMÁCIA', 'FARMÁCIA E BIOQUÍMICA',
#        'FILOSOFIA', 'FISIOTERAPIA', 'FONOAUDIOLOGIA', 'FOTOGRAFIA',
#        'FUTEBOL', 'FÍSICA', 'FÍSICA MEDICA', 'GASTRONOMIA', 'GEOGRAFIA',
#        'GERONTOLOGIA', 'GERONTOLOGIA - CUIDADO AO IDOSO',
#        'GESTÃO AMBIENTAL', 'GESTÃO COMERCIAL', 'GESTÃO DA AVALIAÇÃO',
#        'GESTÃO DA PRODUÇÃO INDUSTRIAL', 'GESTÃO DA QUALIDADE',
#        'GESTÃO DA TECNOLOGIA DA INFORMAÇÃO', 'GESTÃO DE AGRONEGÓCIOS',
#        'GESTÃO DE COOPERATIVAS', 'GESTÃO DE EQUINOCULTURA',
#        'GESTÃO DE MARKETING', 'GESTÃO DE MARKETING EM MÍDIAS DIGITAIS',
#        'GESTÃO DE NEGÓCIOS E INOVAÇÃO', 'GESTÃO DE PRODUÇÃO INDUSTRIAL',
#        'GESTÃO DE RECURSOS HUMANOS', 'GESTÃO DE SAÚDE PÚBLICA',
#        'GESTÃO DE SEGURANÇA PRIVADA',
#        'GESTÃO DE SERVIÇOS JUDICIÁRIOS E NOTARIAIS',
#        'GESTÃO DE SERVIÇOS JURÍDICOS',
#        'GESTÃO DE SERVIÇOS JURÍDICOS E NOTARIAIS',
#        'GESTÃO DE SERVIÇOS JURÍDICOS, NOTARIAIS E DE REGISTRO',
#        'GESTÃO DE TURISMO', 'GESTÃO DESPORTIVA E DE LAZER',
#        'GESTÃO DO AGRONEGÓCIO', 'GESTÃO E EMPREENDEDORISMO',
#        'GESTÃO EM LOGÍSTICA', 'GESTÃO EM SAÚDE AMBIENTAL',
#        'GESTÃO EM VIGILÃNCIA EM SAÚDE', 'GESTÃO EXECUTIVA DE NEGÓCIOS',
#        'GESTÃO FINANCEIRA', 'GESTÃO HOSPITALAR', 'GESTÃO PORTUÁRIA',
#        'GESTÃO PÚBLICA', 'HISTÓRIA', 'HOTELARIA', 'INFORMÁTICA',
#        'INTERDISCIPLINAR EM CIÊNCIAS E HUMANIDADES - BI/LI',
#        'INTERDISCIPLINAR EM HUMANIDADES, ARTES E TECNOLOGIA',
#        'INTERDISCIPLINAR EM NEGÓCIOS', 'INTERDISCIPLINAR EM SAÚDE',
#        'INVESTIGAÇÃO FORENSE E PERÍCIA CRIMINAL',
#        'INVESTIGAÇÃO PROFISSIONAL', 'JOGOS DIGITAIS', 'JORNALISMO',
#        'JORNALISMO DIGITAL', 'LETRAS', 'LETRAS - ESPANHOL',
#        'LETRAS - INGLÊS', 'LETRAS - LIBRAS', 'LETRAS - LÍNGUA INGLESA',
#        'LETRAS - LÍNGUA INGLESA E RESPECTIVAS LITERATURAS',
#        'LETRAS - LÍNGUA PORTUGUESA', 'LETRAS - PORTUGUÊS',
#        'LETRAS - PORTUGUÊS E ALEMÃO', 'LETRAS - PORTUGUÊS E ESPANHOL',
#        'LETRAS - PORTUGUÊS E INGLÊS', 'LETRAS - PORTUGUÊS E JAPONÊS',
#        'LETRAS - TRADUTOR E INTERPRETE',
#        'LETRAS - TRADUÇÃO INGLÊS E PORTUGUÊS',
#        'LETRAS COM PORTUGUÊS E ESPANHOL', 'LETRAS PORTUGUÊS E INGLÊS',
#        'LOGÍSTICA', 'MANUTENÇÃO DE AERONAVES', 'MANUTENÇÃO INDUSTRIAL',
#        'MARKETING', 'MARKETING DIGITAL', 'MARKETING E PUBLICIDADE',
#        'MATEMÁTICA', 'MECATRÔNICA INDUSTRIAL', 'MEDIAÇÃO', 'MEDICINA',
#        'MEDICINA VETERINÁRIA', 'MINISTERIO PASTORAL', 'MODA',
#        'MUSEOLOGIA', 'MUSICOTERAPIA', 'MÍDIAS DIGITAIS', 'MÚSICA',
#        'MÚSICA - CANTO', 'MÚSICA - CORDAS', 'MÚSICA - INSTRUMENTO',
#        'MÚSICA - MÚSICA POPULAR BRASILEIRA', 'MÚSICA - PRODUÇÃO MUSICAL',
#        'MÚSICA - REGÊNCIA', 'NATUROLOGIA', 'NEGÓCIOS DA MODA',
#        'NEGÓCIOS DIGITAIS', 'NEGÓCIOS IMOBILIÁRIOS',
#        'NEGÓCIOS INTERNACIONAIS', 'NUTRIÇÃO', 'ODONTOLOGIA', 'OFTÁLMICA',
#        'ONTOPSICOLOGIA', 'OPTOMETRIA', 'PEDAGOGIA', 'PETRÓLEO E GÁS',
#        'PILOTAGEM PROFISSIONAL DE AERONAVES',
#        'PLANEJAMENTO LOGÍSTICO DE CARGAS', 'PODOLOGIA',
#        'PROCESSOS ESCOLARES', 'PROCESSOS GERENCIAIS',
#        'PROCESSOS METALÚRGICOS', 'PROCESSOS QUÍMICOS',
#        'PRODUÇÃO AUDIOVISUAL', 'PRODUÇÃO CERVEJEIRA', 'PRODUÇÃO CULTURAL',
#        'PRODUÇÃO DE CACAU E CHOCOLATE', 'PRODUÇÃO FONOGRÁFICA',
#        'PRODUÇÃO MULTIMÍDIA', 'PRODUÇÃO PUBLICITÁRIA',
#        'PROPAGANDA E MARKETING', 'PSICOLOGIA', 'PSICOPEDAGOGIA',
#        'PUBLICIDADE E PROPAGANDA', 'QUIROPRAXIA', 'QUÍMICA',
#        'QUÍMICA INDUSTRIAL', 'QUÍMICA TECNOLÓGICA', 'RADIOLOGIA',
#        'REDES DE COMPUTADORES', 'REFRIGERAÇÃO E CLIMATIZAÇÃO',
#        'RELAÇÕES INTERNACIONAIS', 'RELAÇÕES PÚBLICAS',
#        'RÁDIO, TV E INTERNET', 'SANEAMENTO AMBIENTAL', 'SECRETARIADO',
#        'SECRETARIADO EXECUTIVO', 'SECRETARIADO EXECUTIVO - BILÍNGUE',
#        'SECRETARIADO EXECUTIVO BILINGUE - PORTUGUÊS/INGLÊS',
#        'SECRETARIADO EXECUTIVO TRILÍNGUE', 'SEGURANÇA ALIMENTAR',
#        'SEGURANÇA DA INFORMAÇÃO', 'SEGURANÇA NO TRABALHO',
#        'SEGURANÇA NO TRÃNSITO', 'SEGURANÇA PRIVADA', 'SEGURANÇA PÚBLICA',
#        'SERVIÇO SOCIAL', 'SERVIÇOS JUDICIAIS', 'SERVIÇOS JURÍDICOS',
#        'SERVIÇOS JURÍDICOS E NOTARIAIS',
#        'SERVIÇOS JURÍDICOS, CARTORÁRIOS E NOTARIAIS',
#        'SERVIÇOS JURÍDICOS, NOTARIAS E DE REGISTRO',
#        'SERVIÇOS REGISTRAIS E NOTARIAIS', 'SISTEMA DE INFORMAÇÃO',
#        'SISTEMAS BIOMEDICOS', 'SISTEMAS DE INFORMAÇÃO',
#        'SISTEMAS PARA INTERNET', 'SOCIOLOGIA', 'SOLDAGEM', 'TEATRO',
#        'TECNÓLOGO EM METALURGIA', 'TEOLOGIA',
#        'TEOLOGIA: DOUTRINA CATÓLICA', 'TERAPIA OCUPACIONAL',
#        'TERAPIAS INTEGRATIVAS E COMPLEMENTARES', 'TRADUTOR E INTERPRETE',
#        'TRADUÇÃO E INTERPRETAÇÃO',
#        'TRADUÇÃO E INTERPRETAÇÃO - PORTUGUÊS/INGLÊS', 'TURISMO',
#        'VISAGISMO E TERAPIAS CAPILARES', 'ZOOTECNIA',
#        'ÓPTICA E OPTOMETRIA'], dtype=object)

# %%
# Ajustando a grafia dos cursos: ADMINISTRAÇÃO, CIÊNCIA DA COMPUTAÇÃO, CIÊNCIAS ECONÔMICAS, ENGENHARIA DE ENERGIA, SISTEMAS DE INFORMAÇÃO, ENGENHARIA DE COMPUTAÇÃO,
# LETRAS - INGLÊS, LETRAS - PORTUGUÊS, LETRAS - PORTUGUÊS E ESPANHOL, LETRAS - PORTUGUÊS E INGLÊS

prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'ADMINISTRAÇÃO DE EMPRESAS', 'NOME_CURSO_BOLSA'] = 'ADMINISTRAÇÃO'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'CIÊNCIAS DA COMPUTAÇÃO', 'NOME_CURSO_BOLSA'] = 'CIÊNCIA DA COMPUTAÇÃO'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'CIÊNCIA ECONÔMICA', 'NOME_CURSO_BOLSA'] = 'CIÊNCIAS ECONÔMICAS'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'ENGENHARIA DA COMPUTAÇÃO', 'NOME_CURSO_BOLSA'] = 'ENGENHARIA DE COMPUTAÇÃO'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'ENGENHARIA DE ENERGIAS', 'NOME_CURSO_BOLSA'] = 'ENGENHARIA DE ENERGIA'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'LETRAS - LÍNGUA INGLESA', 'NOME_CURSO_BOLSA'] = 'LETRAS - INGLÊS'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'LETRAS - LÍNGUA PORTUGUESA', 'NOME_CURSO_BOLSA'] = 'LETRAS - PORTUGUÊS'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'LETRAS COM PORTUGUÊS E ESPANHOL', 'NOME_CURSO_BOLSA'] = 'LETRAS - PORTUGUÊS E ESPANHOL'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'LETRAS PORTUGUÊS E INGLÊS', 'NOME_CURSO_BOLSA'] = 'LETRAS - PORTUGUÊS E INGLÊS'
prouni_2020.loc[prouni_2020['NOME_CURSO_BOLSA'] == 'SISTEMA DE INFORMAÇÃO', 'NOME_CURSO_BOLSA'] = 'SISTEMAS DE INFORMAÇÃO'

# %%
# Quantidade de cursos únicos após tratamento

prouni_2020['NOME_CURSO_BOLSA'].nunique()
# Out:
# 307

# %% [markdown]
# ### Ajustando Raça, Gênero e Deficiência

# %% [markdown]
# Padronização e correção das informações

# %% [markdown]
# Raça

# %%
prouni_2020['RACA_BENEFICIARIO'].unique()
# Out:
# array(['Parda', 'Branca', 'Preta', 'Amarela', 'Não Informada', 'Ind¡gena'],
#       dtype=object)

# %%
# Ajustando o termo 'Ind¡gena'

prouni_2020.loc[prouni_2020['RACA_BENEFICIARIO'] == 'Ind¡gena', 'RACA_BENEFICIARIO'] = 'Indígena'

# %% [markdown]
# Gênero

# %%
prouni_2020['SEXO_BENEFICIARIO'] = prouni_2020['SEXO_BENEFICIARIO'].replace({'F': 'Feminino', 'M': 'Masculino'})
prouni_2020.head(2)
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA              NOME_IES_BOLSA  \
# 0                 2020                    322       UNIVERSIDADE PAULISTA
# 1                 2020                    163  UNIVERSIDADE ESTÁCIO DE SÁ
#
#    MUNICIPIO               CAMPUS TIPO_BOLSA MODALIDADE_ENSINO_BOLSA  \
# 0   IPATINGA             IPATINGA   INTEGRAL                     EAD
# 1  FORTALEZA  EAD VIA CORPVS - CE   INTEGRAL                     EAD
#
#   NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA CPF_BENEFICIARIO SEXO_BENEFICIARIO  \
# 0        PEDAGOGIA      CURSO A DISTÂNCIA   991.XXX.XXX-91          Feminino
# 1        MARKETING      CURSO A DISTÂNCIA   067.XXX.XXX-01         Masculino
#
#   RACA_BENEFICIARIO DATA_NASCIMENTO BENEFICIARIO_DEFICIENTE_FISICO  \
# 0             Parda      1973-08-11                              N
# 1             Parda      1987-05-13                              N
#
#   REGIAO_BENEFICIARIO UF_BENEFICIARIO MUNICIPIO_BENEFICIARIO  IDADE  \
# 0             SUDESTE              MG   GOVERNADOR VALADARES     47
# 1            NORDESTE              CE              FORTALEZA     33
#
#         FAIXA_ETARIA
# 0  04. Entre 41 e 50
# 1  03. Entre 31 e 40

# %% [markdown]
# Deficiência

# %%
prouni_2020['BENEFICIARIO_DEFICIENTE_FISICO'] = prouni_2020['BENEFICIARIO_DEFICIENTE_FISICO'].replace({'S': 'Sim', 'N': 'Não'})
prouni_2020.head(2)
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA              NOME_IES_BOLSA  \
# 0                 2020                    322       UNIVERSIDADE PAULISTA
# 1                 2020                    163  UNIVERSIDADE ESTÁCIO DE SÁ
#
#    MUNICIPIO               CAMPUS TIPO_BOLSA MODALIDADE_ENSINO_BOLSA  \
# 0   IPATINGA             IPATINGA   INTEGRAL                     EAD
# 1  FORTALEZA  EAD VIA CORPVS - CE   INTEGRAL                     EAD
#
#   NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA CPF_BENEFICIARIO SEXO_BENEFICIARIO  \
# 0        PEDAGOGIA      CURSO A DISTÂNCIA   991.XXX.XXX-91          Feminino
# 1        MARKETING      CURSO A DISTÂNCIA   067.XXX.XXX-01         Masculino
#
#   RACA_BENEFICIARIO DATA_NASCIMENTO BENEFICIARIO_DEFICIENTE_FISICO  \
# 0             Parda      1973-08-11                            Não
# 1             Parda      1987-05-13                            Não
#
#   REGIAO_BENEFICIARIO UF_BENEFICIARIO MUNICIPIO_BENEFICIARIO  IDADE  \
# 0             SUDESTE              MG   GOVERNADOR VALADARES     47
# 1            NORDESTE              CE              FORTALEZA     33
#
#         FAIXA_ETARIA
# 0  04. Entre 41 e 50
# 1  03. Entre 31 e 40

# %% [markdown]
# ## Perfil das Concessões

# %% [markdown]
# ### Gênero

# %%
genero_qtd = prouni_2020['SEXO_BENEFICIARIO'].value_counts()
genero_percent = (genero_qtd / genero_qtd.sum() * 100).round(2)

df_genero = pd.DataFrame({
    'QTD': genero_qtd,
    '%': genero_percent
})
df_genero = df_genero.reset_index()
df_genero
# Out:
#   SEXO_BENEFICIARIO     QTD      %
# 0          Feminino  101113  60.63
# 1         Masculino   65670  39.37

# %%
fig_genero = px.pie(df_genero, values = 'QTD', names = 'SEXO_BENEFICIARIO', color_discrete_sequence = px.colors.qualitative.T10, hole = 0.1)

fig_genero.update_traces(textinfo='percent+value+label')

fig_genero.update_layout(
    title_text = '<b> Concessão por Gênero </b>',
    title_font_size = 15,
    font_size = 13,
    height = 350,
    width = 700,
    template = 'simple_white',
    showlegend = False
)

fig_genero.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d5ab582f-e489-4190-977a-fcf29669e48a" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d5ab582f-e489-4190-977a-fcf29669e48a")) {                    Plotly.newPlot(                        "d5ab582f-e489-4190-977a-fcf29669e48a",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"SEXO_BENEFICIARIO=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Feminino","Masculino"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"+YoBAIYAAQA="},"type":"pie","textinfo":"percent+value+label"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"marker":{"colorbar":{"out ...

# %% [markdown]
# ### Faixa Etária

# %%
prouni_2020[['IDADE', 'FAIXA_ETARIA', 'DATA_NASCIMENTO']].head(4)
# Out:
#    IDADE       FAIXA_ETARIA DATA_NASCIMENTO
# 0     47  04. Entre 41 e 50      1973-08-11
# 1     33  03. Entre 31 e 40      1987-05-13
# 2     19  01. Entre 15 e 20      2001-07-23
# 3     17  01. Entre 15 e 20      2003-04-04

# %%
faixa_etaria_qtd = prouni_2020['FAIXA_ETARIA'].value_counts()
faixa_etaria_percent = (faixa_etaria_qtd / faixa_etaria_qtd.sum() * 100).round(3)

df_faixa_etaria = pd.DataFrame({
    'QTD': faixa_etaria_qtd,
    '%': faixa_etaria_percent
})
df_faixa_etaria.sort_values(by = 'FAIXA_ETARIA')
df_faixa_etaria = df_faixa_etaria.reset_index()
df_faixa_etaria
# Out:
#         FAIXA_ETARIA    QTD       %
# 0  01. Entre 15 e 20  83469  50.046
# 1  02. Entre 21 e 30  63900  38.313
# 2  03. Entre 31 e 40  13739   8.238
# 3  04. Entre 41 e 50   4307   2.582
# 4    05. Acima de 50   1368   0.820

# %%
df_faixa_etaria = df_faixa_etaria.reset_index()

fig_faixa_etaria = go.Figure()
fig_faixa_etaria.add_trace(go.Bar(x = df_faixa_etaria['FAIXA_ETARIA'], y = df_faixa_etaria['QTD'], name = 'Faixa Etária', marker_color = '#296073', text = df_faixa_etaria['QTD'],
                            texttemplate = '%{y:.0f} <br> (%{customdata:.2f}%)', customdata = df_faixa_etaria['%']))  # formatando rótulo com QTD e % e pulando linha entre eles

fig_faixa_etaria.update_layout(
    title = '<b> Concessão por Faixa Etária </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white',
    height = 450,
    width = 800
)

fig_faixa_etaria.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b930ef6a-3f96-4539-be8d-8afe1a9ee7de" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b930ef6a-3f96-4539-be8d-8afe1a9ee7de")) {                    Plotly.newPlot(                        "b930ef6a-3f96-4539-be8d-8afe1a9ee7de",                        [{"customdata":{"dtype":"f8","bdata":"2c73U+MFSUDy0k1iEChDQGDl0CLbeSBADi2yne+nBEA9CtejcD3qPw=="},"marker":{"color":"#296073"},"name":"Faixa Etária","text":{"dtype":"f8","bdata":"AAAAANBg9EAAAAAAgDPvQAAAAACA1cpAAAAAAADTsEAAAAAAAGCVQA=="},"texttemplate":"%{y:.0f} \u003cbr\u003e (%{customdata:.2f}%)","x":["01. Entre 15 e 20","02. Entre 21 e 30","03. Entre 31 e 40","04. Entre 41 e 50","05. Acima de 50"],"y":{"dtype":"i4","bdata":"DUYBAJz5AACrNQAA0xAAAFgFAAA="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true," ...

# %% [markdown]
# % por Faixa Etária e por Gênero

# %%
df_faixa_etaria_gen = (pd.crosstab(prouni_2020['FAIXA_ETARIA'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
df_faixa_etaria_gen = df_faixa_etaria_gen.reset_index()
df_faixa_etaria_gen
# Out:
# SEXO_BENEFICIARIO       FAIXA_ETARIA  Feminino  Masculino
# 0                  01. Entre 15 e 20     64.18      35.82
# 1                  02. Entre 21 e 30     56.98      43.02
# 2                  03. Entre 31 e 40     55.97      44.03
# 3                  04. Entre 41 e 50     60.30      39.70
# 4                    05. Acima de 50     61.48      38.52

# %%
fig_faixa_etaria_gen = go.Figure()

fig_faixa_etaria_gen.add_trace(go.Bar(x = df_faixa_etaria_gen['Feminino'], y = df_faixa_etaria_gen['FAIXA_ETARIA'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                                     text=df_faixa_etaria_gen['Feminino'], textposition='outside'))

fig_faixa_etaria_gen.add_trace(go.Bar(x = df_faixa_etaria_gen['Masculino'], y = df_faixa_etaria_gen['FAIXA_ETARIA'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                                     text=df_faixa_etaria_gen['Masculino'], textposition='inside'))

fig_faixa_etaria_gen.update_layout(
    title = '<b> % Concessão por Faixa Etária e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_faixa_etaria_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="1166a88a-312d-4595-aa0a-7ebdf8450c31" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1166a88a-312d-4595-aa0a-7ebdf8450c31")) {                    Plotly.newPlot(                        "1166a88a-312d-4595-aa0a-7ebdf8450c31",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"7FG4HoULUEA9CtejcH1MQFyPwvUo\u002fEtAZmZmZmYmTkA9CtejcL1OQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"7FG4HoULUEA9CtejcH1MQFyPwvUo\u002fEtAZmZmZmYmTkA9CtejcL1OQA=="},"y":["01. Entre 15 e 20","02. Entre 21 e 30","03. Entre 31 e 40","04. Entre 41 e 50","05. Acima de 50"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"KVyPwvXoQUDD9Shcj4JFQKRwPQrXA0ZAmpmZmZnZQ0DD9Shcj0JDQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"KVyPwvXoQUDD9Shcj4JFQKRwPQrXA0ZAmpmZmZnZQ0DD9Shcj0JDQA=="},"y":["01. Entre 15 e 20","02. Entre 21 e 30","03. Entre 31 e 40","04. Entre 41 e 50","05. Acima de 50"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line" ...

# %% [markdown]
# ### Raça

# %%
raca_qtd = prouni_2020['RACA_BENEFICIARIO'].value_counts()
raca_percent = (raca_qtd / raca_qtd.sum() * 100).round(2)

df_raca = pd.DataFrame({
    'QTD': raca_qtd,
    '%': raca_percent
})
df_raca = df_raca.reset_index()
df_raca
# Out:
#   RACA_BENEFICIARIO    QTD      %
# 0             Parda  78053  46.80
# 1            Branca  64459  38.65
# 2             Preta  21151  12.68
# 3           Amarela   2900   1.74
# 4          Indígena    153   0.09
# 5     Não Informada     67   0.04

# %%
fig_raca = go.Figure()
fig_raca.add_trace(go.Bar(x = df_raca['RACA_BENEFICIARIO'], y = df_raca['QTD'], name = 'Raça', marker_color = '#296073', text = df_raca['QTD'],
                            texttemplate = '%{y:.0f} <br> (%{customdata:.2f}%)', customdata = df_raca['%']))  # formatando rótulo com QTD e % e pulando linha entre eles

fig_raca.update_layout(
    title = '<b> Concessão por Raça </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white',
    height = 450,
    width = 800
)

fig_raca.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="02d9891a-4793-4391-a794-345409096975" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("02d9891a-4793-4391-a794-345409096975")) {                    Plotly.newPlot(                        "02d9891a-4793-4391-a794-345409096975",                        [{"customdata":{"dtype":"f8","bdata":"ZmZmZmZmR0AzMzMzM1NDQFyPwvUoXClA16NwPQrX+z8K16NwPQq3P3sUrkfheqQ\u002f"},"marker":{"color":"#296073"},"name":"Raça","text":{"dtype":"f8","bdata":"AAAAAFAO80AAAAAAYHnvQAAAAADAp9RAAAAAAACopkAAAAAAACBjQAAAAAAAwFBA"},"texttemplate":"%{y:.0f} \u003cbr\u003e (%{customdata:.2f}%)","x":["Parda","Branca","Preta","Amarela","Indígena","Não Informada"],"y":{"dtype":"i4","bdata":"5TABAMv7AACfUgAAVAsAAJkAAABDAAAA"},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scat ...

# %% [markdown]
# % por Raça e por Gênero

# %%
raca_gen = (pd.crosstab(prouni_2020['RACA_BENEFICIARIO'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
raca_gen = raca_gen.reset_index()

fig_raca_gen = go.Figure()

fig_raca_gen.add_trace(go.Bar(x = raca_gen['Feminino'], y = raca_gen['RACA_BENEFICIARIO'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                              text=raca_gen['Feminino'], textposition='outside'))

fig_raca_gen.add_trace(go.Bar(x = raca_gen['Masculino'], y = raca_gen['RACA_BENEFICIARIO'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                              text=raca_gen['Masculino'], textposition='inside'))

fig_raca_gen.update_layout(
    title = '<b> % Concessão por Raça e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_raca_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b4c83136-b1a9-4cc8-a45e-ee1c5dcda447" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b4c83136-b1a9-4cc8-a45e-ee1c5dcda447")) {                    Plotly.newPlot(                        "b4c83136-b1a9-4cc8-a45e-ee1c5dcda447",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"9ihcj8LlUECF61G4HsVOQHsUrkfhqlBAKVyPwvXoUUBSuB6F6xFOQM3MzMzMTE1A"},"textposition":"outside","x":{"dtype":"f8","bdata":"9ihcj8LlUECF61G4HsVOQHsUrkfhqlBAKVyPwvXoUUBSuB6F6xFOQM3MzMzMTE1A"},"y":["Amarela","Branca","Indígena","Não Informada","Parda","Preta"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"FK5H4Xo0QEB7FK5H4TpDQArXo3A9qkBAXI\u002fC9ShcPECuR+F6FO5DQDMzMzMzs0RA"},"textposition":"inside","x":{"dtype":"f8","bdata":"FK5H4Xo0QEB7FK5H4TpDQArXo3A9qkBAXI\u002fC9ShcPECuR+F6FO5DQDMzMzMzs0RA"},"y":["Amarela","Branca","Indígena","Não Informada","Parda","Preta"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":" ...

# %% [markdown]
# ### Deficiência

# %%
def_qtd = prouni_2020['BENEFICIARIO_DEFICIENTE_FISICO'].value_counts()
def_percent = (def_qtd / def_qtd.sum() * 100).round(2)

df_deficiencia = pd.DataFrame({
    'QTD': def_qtd,
    '%': def_percent
})
df_deficiencia = df_deficiencia.reset_index()
df_deficiencia
# Out:
#   BENEFICIARIO_DEFICIENTE_FISICO     QTD      %
# 0                            Não  165511  99.24
# 1                            Sim    1272   0.76

# %%
fig_deficiencia = go.Figure(go.Pie(
    labels = df_deficiencia['BENEFICIARIO_DEFICIENTE_FISICO'],
    values = df_deficiencia['QTD'],
    hole = 0.4,
    textinfo = 'percent+value+label',
    rotation = 90    # Rotacionar o gráfico
))

fig_deficiencia.update_layout(
    title_text = '<b> Concessão por Pessoas com Deficiência </b>',
    title_font_size = 15,
    font_size = 13,
    height = 350,
    width = 700,
    template = 'simple_white',
    showlegend = False
)

fig_deficiencia.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="bed62a1a-62be-4d09-86c9-4e8893196de6" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bed62a1a-62be-4d09-86c9-4e8893196de6")) {                    Plotly.newPlot(                        "bed62a1a-62be-4d09-86c9-4e8893196de6",                        [{"hole":0.4,"labels":["Não","Sim"],"rotation":90,"textinfo":"percent+value+label","values":{"dtype":"i4","bdata":"h4YCAPgEAAA="},"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"marker":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type ...

# %%
# % de Pessoas com deficiência por Gênero

deficiencia_gen = (pd.crosstab(prouni_2020['BENEFICIARIO_DEFICIENTE_FISICO'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
deficiencia_gen = deficiencia_gen.reset_index()
deficiencia_gen
# Out:
# SEXO_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  Feminino  Masculino
# 0                                            Não     60.74      39.26
# 1                                            Sim     45.20      54.80

# %%
# % de Pessoas com Deficiência por Gênero

fig_deficiencia_gen = go.Figure()

fig_deficiencia_gen.add_trace(go.Bar(x = deficiencia_gen['Feminino'], y = deficiencia_gen['BENEFICIARIO_DEFICIENTE_FISICO'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                                     text=deficiencia_gen['Feminino'], textposition='outside'))

fig_deficiencia_gen.add_trace(go.Bar(x = deficiencia_gen['Masculino'], y = deficiencia_gen['BENEFICIARIO_DEFICIENTE_FISICO'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                                     text=deficiencia_gen['Masculino'], textposition='inside'))

fig_deficiencia_gen.update_layout(
    title = '<b> % Concessão por Pessoas com Deficiência e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_deficiencia_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="6699facf-b348-4737-9387-451b94952a31" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6699facf-b348-4737-9387-451b94952a31")) {                    Plotly.newPlot(                        "6699facf-b348-4737-9387-451b94952a31",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"H4XrUbheTkCamZmZmZlGQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"H4XrUbheTkCamZmZmZlGQA=="},"y":["Não","Sim"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"4XoUrkehQ0BmZmZmZmZLQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"4XoUrkehQ0BmZmZmZmZLQA=="},"y":["Não","Sim"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type" ...

# %% [markdown]
# ### Tipo de Bolsa

# %%
tipo_qtd = prouni_2020['TIPO_BOLSA'].value_counts()
tipo_percent = (tipo_qtd / tipo_qtd.sum() * 100).round(2)

df_tipo = pd.DataFrame({
    'QTD': tipo_qtd,
    '%': tipo_percent
})
df_tipo = df_tipo.reset_index()
df_tipo
# Out:
#   TIPO_BOLSA     QTD      %
# 0   INTEGRAL  130704  78.37
# 1    PARCIAL   36079  21.63

# %%
fig_tipo_bolsa = px.pie(df_tipo, values = 'QTD', names = 'TIPO_BOLSA', color_discrete_sequence = px.colors.qualitative.T10, hole = 0.1)

fig_tipo_bolsa.update_traces(textinfo = 'percent+value+label')

fig_tipo_bolsa.update_layout(
    title_text = '<b> Concessão por Tipo de Bolsa </b>',
    title_font_size = 15,
    font_size = 13,
    height = 350,
    width = 700,
    template = 'simple_white',
    showlegend = False
)

fig_tipo_bolsa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="4938fae6-7a93-4a72-9acf-e9071378dd99" class="plotly-graph-div" style="height:350px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4938fae6-7a93-4a72-9acf-e9071378dd99")) {                    Plotly.newPlot(                        "4938fae6-7a93-4a72-9acf-e9071378dd99",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"TIPO_BOLSA=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["INTEGRAL","PARCIAL"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"kP4BAO+MAAA="},"type":"pie","textinfo":"percent+value+label"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"marker":{"colorbar":{"outlinewidth ...

# %% [markdown]
# % por Tipo de Bolsa e por Gênero

# %%
df_tipo_gen = (pd.crosstab(prouni_2020['TIPO_BOLSA'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
df_tipo_gen = df_tipo_gen.reset_index()
df_tipo_gen
# Out:
# SEXO_BENEFICIARIO TIPO_BOLSA  Feminino  Masculino
# 0                   INTEGRAL     60.08      39.92
# 1                    PARCIAL     62.60      37.40

# %%
fig_tipo_gen = go.Figure()

fig_tipo_gen.add_trace(go.Bar(x = df_tipo_gen['Feminino'], y = df_tipo_gen['TIPO_BOLSA'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                              text=df_tipo_gen['Feminino'], textposition='outside'))

fig_tipo_gen.add_trace(go.Bar(x = df_tipo_gen['Masculino'], y = df_tipo_gen['TIPO_BOLSA'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                              text=df_tipo_gen['Masculino'], textposition='inside'))

fig_tipo_gen.update_layout(
    title = '<b> % Concessão por Tipo da Bolsa e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_tipo_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="618b0228-dcfa-4cee-8069-e30f255db278" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("618b0228-dcfa-4cee-8069-e30f255db278")) {                    Plotly.newPlot(                        "618b0228-dcfa-4cee-8069-e30f255db278",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"CtejcD0KTkDNzMzMzExPQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"CtejcD0KTkDNzMzMzExPQA=="},"y":["INTEGRAL","PARCIAL"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"9ihcj8L1Q0AzMzMzM7NCQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"9ihcj8L1Q0AzMzMzM7NCQA=="},"y":["INTEGRAL","PARCIAL"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"autom ...

# %% [markdown]
# ### Modalidade de Ensino

# %%
modalidade_qtd = prouni_2020['MODALIDADE_ENSINO_BOLSA'].value_counts()
modalidade_percent = (modalidade_qtd / modalidade_qtd.sum() * 100).round(2)

df_modalidade = pd.DataFrame({
    'QTD': modalidade_qtd,
    '%': modalidade_percent
})
df_modalidade = df_modalidade.reset_index()
df_modalidade
# Out:
#   MODALIDADE_ENSINO_BOLSA     QTD      %
# 0              PRESENCIAL  112965  67.73
# 1                     EAD   53818  32.27

# %%
fig_modalidade = px.pie(df_modalidade, values = 'QTD', names = 'MODALIDADE_ENSINO_BOLSA', color_discrete_sequence = px.colors.qualitative.T10, hole = 0.1)

fig_modalidade.update_traces(textinfo = 'percent+value+label')

fig_modalidade.update_layout(
    title_text = '<b> Concessão por Modalidade </b>',
    title_font_size = 15,
    font_size = 13,
    height = 360,
    width = 700,
    template = 'simple_white',
    showlegend = False
)

fig_modalidade.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="241fba73-19f9-4d72-99a3-158d868755fd" class="plotly-graph-div" style="height:360px; width:700px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("241fba73-19f9-4d72-99a3-158d868755fd")) {                    Plotly.newPlot(                        "241fba73-19f9-4d72-99a3-158d868755fd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"MODALIDADE_ENSINO_BOLSA=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["PRESENCIAL","EAD"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"RbkBADrSAAA="},"type":"pie","textinfo":"percent+value+label"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"marker":{"colorbar":{"o ...

# %% [markdown]
# % por Modalidade e por Gênero

# %%
df_modalidade_gen = (pd.crosstab(prouni_2020['MODALIDADE_ENSINO_BOLSA'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
df_modalidade_gen = df_modalidade_gen.reset_index()
df_modalidade_gen
# Out:
# SEXO_BENEFICIARIO MODALIDADE_ENSINO_BOLSA  Feminino  Masculino
# 0                                     EAD     61.44      38.56
# 1                              PRESENCIAL     60.24      39.76

# %%
fig_modalidade_gen = go.Figure()

fig_modalidade_gen.add_trace(go.Bar(x = df_modalidade_gen['Feminino'], y = df_modalidade_gen['MODALIDADE_ENSINO_BOLSA'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                              text=df_modalidade_gen['Feminino'], textposition='outside'))

fig_modalidade_gen.add_trace(go.Bar(x = df_modalidade_gen['Masculino'], y = df_modalidade_gen['MODALIDADE_ENSINO_BOLSA'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                              text=df_modalidade_gen['Masculino'], textposition='inside'))

fig_modalidade_gen.update_layout(
    title = '<b> % Concessão por Modalidade e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_modalidade_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="e1e54caa-1432-4e7b-a5ae-18fef1a5893d" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e1e54caa-1432-4e7b-a5ae-18fef1a5893d")) {                    Plotly.newPlot(                        "e1e54caa-1432-4e7b-a5ae-18fef1a5893d",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"uB6F61G4TkAfhetRuB5OQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"uB6F61G4TkAfhetRuB5OQA=="},"y":["EAD","PRESENCIAL"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"SOF6FK5HQ0DhehSuR+FDQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"SOF6FK5HQ0DhehSuR+FDQA=="},"y":["EAD","PRESENCIAL"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargi ...

# %% [markdown]
# % por Modalidade e por Tipo da Bolsa

# %%
df_modalidade_tipo = (pd.crosstab(prouni_2020['MODALIDADE_ENSINO_BOLSA'], prouni_2020['TIPO_BOLSA'], normalize='index') * 100).round(2)
df_modalidade_tipo = df_modalidade_tipo.reset_index()
df_modalidade_tipo
# Out:
# TIPO_BOLSA MODALIDADE_ENSINO_BOLSA  INTEGRAL  PARCIAL
# 0                              EAD     93.77     6.23
# 1                       PRESENCIAL     71.03    28.97

# %%
fig_modalidade_tipo = go.Figure()

fig_modalidade_tipo.add_trace(go.Bar(x = df_modalidade_tipo['INTEGRAL'], y = df_modalidade_tipo['MODALIDADE_ENSINO_BOLSA'], name = 'Integral', marker_color = '#f49432', orientation = 'h',
                              text=df_modalidade_tipo['INTEGRAL'], textposition='outside'))

fig_modalidade_tipo.add_trace(go.Bar(x = df_modalidade_tipo['PARCIAL'], y = df_modalidade_tipo['MODALIDADE_ENSINO_BOLSA'], name = 'Parcial', marker_color = '#296073', orientation = 'h',
                              text=df_modalidade_tipo['PARCIAL'], textposition='inside'))

fig_modalidade_tipo.update_layout(
    title = '<b> % Concessão por Modalidade e Tipo da Bolsa </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_modalidade_tipo.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="8d09c9bd-2ec4-442e-9b6b-c6b8c5ff8723" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8d09c9bd-2ec4-442e-9b6b-c6b8c5ff8723")) {                    Plotly.newPlot(                        "8d09c9bd-2ec4-442e-9b6b-c6b8c5ff8723",                        [{"marker":{"color":"#f49432"},"name":"Integral","orientation":"h","text":{"dtype":"f8","bdata":"4XoUrkdxV0BSuB6F68FRQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"4XoUrkdxV0BSuB6F68FRQA=="},"y":["EAD","PRESENCIAL"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Parcial","orientation":"h","text":{"dtype":"f8","bdata":"7FG4HoXrGEC4HoXrUfg8QA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"7FG4HoXrGEC4HoXrUfg8QA=="},"y":["EAD","PRESENCIAL"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin" ...

# %%
fig = make_subplots(
    rows=1, cols=3,
    subplot_titles=[
        'Concessão por Gênero',
        'Concessão por Modalidade',
        'Concessão por Tipo de Bolsa'],
    specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]],
    horizontal_spacing = 0.1)    # Ajuste do espaçamento horizontal entre os gráficos

fig_genero = px.pie(df_genero, values='QTD', names='SEXO_BENEFICIARIO', color_discrete_sequence=px.colors.qualitative.T10, hole=0.1)
fig.add_trace(fig_genero.data[0], row=1, col=1)

fig_modalidade = px.pie(df_modalidade, values='QTD', names='MODALIDADE_ENSINO_BOLSA', color_discrete_sequence=px.colors.qualitative.T10, hole=0.1)
fig.add_trace(fig_modalidade.data[0], row=1, col=2)

fig_tipo_bolsa = px.pie(df_tipo, values='QTD', names='TIPO_BOLSA', color_discrete_sequence=px.colors.qualitative.T10, hole=0.1)
fig.add_trace(fig_tipo_bolsa.data[0], row=1, col=3)

fig.update_traces(textinfo='percent+value+label')


fig.update_layout(
    title_text='<b> Concessão de Bolsas </b>',
    title_font_size=18,
    font_size=13,
    height=400,
    width=1000,
    template='simple_white',
    showlegend=False
)

for annotation in fig['layout']['annotations']:
    annotation['y'] = annotation['y'] + 0.05   # Aumenta o espaçamento vertical entre os gráficos e seus títulos

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="9af72bb3-3051-4e2b-95b4-7c0bd7038828" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9af72bb3-3051-4e2b-95b4-7c0bd7038828")) {                    Plotly.newPlot(                        "9af72bb3-3051-4e2b-95b4-7c0bd7038828",                        [{"domain":{"x":[0.0,0.26666666666666666],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"SEXO_BENEFICIARIO=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Feminino","Masculino"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"+YoBAIYAAQA="},"type":"pie","textinfo":"percent+value+label"},{"domain":{"x":[0.3666666666666667,0.6333333333333333],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"MODALIDADE_ENSINO_BOLSA=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["PRESENCIAL","EAD"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"RbkBADrSAAA="},"type":"pie","textinfo":"percent+value+label"},{"domain":{"x":[0.7333333333333334,1.0],"y":[0.0,1.0]},"hole":0.1,"hovertemplate":"TIPO_BOLSA=%{label}\u003cbr\u003eQTD=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["INTEGRAL","PARCIAL"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i4","bdata":"kP4BAO+MAAA="},"type":"pie","textinfo":"percent+value+label"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.222 ...

# %% [markdown]
# ### Turno do Curso

# %%
turno_qtd = prouni_2020['NOME_TURNO_CURSO_BOLSA'].value_counts()
turno_percent = (turno_qtd / turno_qtd.sum() * 100).round(2)

df_turno = pd.DataFrame({
    'QTD': turno_qtd,
    '%': turno_percent
})
df_turno = df_turno.reset_index()
df_turno
# Out:
#   NOME_TURNO_CURSO_BOLSA    QTD      %
# 0                NOTURNO  75313  45.16
# 1      CURSO A DISTÂNCIA  53818  32.27
# 2               MATUTINO  28107  16.85
# 3               INTEGRAL   5930   3.56
# 4             VESPERTINO   3615   2.17

# %%
fig_turno = go.Figure()
fig_turno.add_trace(go.Bar(x = df_turno['NOME_TURNO_CURSO_BOLSA'], y = df_turno['QTD'], name = 'Turno', marker_color = '#296073', text = df_turno['QTD'],
                            texttemplate = '%{y:.0f} <br> (%{customdata:.2f}%)', customdata = df_turno['%']))  # formatando rótulo com QTD e % e pulando linha entre eles

fig_turno.update_layout(
    title = '<b> Concessão por Turno do Curso </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white',
    height = 450,
    width = 800
)

fig_turno.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d14597ef-cd21-4be0-9c61-e906d4726561" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d14597ef-cd21-4be0-9c61-e906d4726561")) {                    Plotly.newPlot(                        "d14597ef-cd21-4be0-9c61-e906d4726561",                        [{"customdata":{"dtype":"f8","bdata":"FK5H4XqURkDD9ShcjyJAQJqZmZmZ2TBAexSuR+F6DEBcj8L1KFwBQA=="},"marker":{"color":"#296073"},"name":"Turno","text":{"dtype":"f8","bdata":"AAAAABBj8kAAAAAAQEfqQAAAAADActtAAAAAAAAqt0AAAAAAAD6sQA=="},"texttemplate":"%{y:.0f} \u003cbr\u003e (%{customdata:.2f}%)","x":["NOTURNO","CURSO A DISTÂNCIA","MATUTINO","INTEGRAL","VESPERTINO"],"y":{"dtype":"i4","bdata":"MSYBADrSAADLbQAAKhcAAB8OAAA="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"col ...

# %% [markdown]
# % por Turno e Gênero

# %%
df_turno_gen = (pd.crosstab(prouni_2020['NOME_TURNO_CURSO_BOLSA'], prouni_2020['SEXO_BENEFICIARIO'], normalize='index') * 100).round(2)
df_turno_gen = df_turno_gen.reset_index()
df_turno_gen
# Out:
# SEXO_BENEFICIARIO NOME_TURNO_CURSO_BOLSA  Feminino  Masculino
# 0                      CURSO A DISTÂNCIA     61.44      38.56
# 1                               INTEGRAL     62.01      37.99
# 2                               MATUTINO     65.85      34.15
# 3                                NOTURNO     57.63      42.37
# 4                             VESPERTINO     67.99      32.01

# %%
fig_turno_gen = go.Figure()

fig_turno_gen.add_trace(go.Bar(x = df_turno_gen['Feminino'], y = df_turno_gen['NOME_TURNO_CURSO_BOLSA'], name = 'Feminino', marker_color = '#f49432', orientation = 'h',
                              text=df_turno_gen['Feminino'], textposition='outside'))

fig_turno_gen.add_trace(go.Bar(x = df_turno_gen['Masculino'], y = df_turno_gen['NOME_TURNO_CURSO_BOLSA'], name = 'Masculino', marker_color = '#296073', orientation = 'h',
                              text=df_turno_gen['Masculino'], textposition='inside'))

fig_turno_gen.update_layout(
    title = '<b> % Concessão por Turno e Gênero </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_turno_gen.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cc4a1577-8399-4406-b9a2-5fa7638c638e" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cc4a1577-8399-4406-b9a2-5fa7638c638e")) {                    Plotly.newPlot(                        "cc4a1577-8399-4406-b9a2-5fa7638c638e",                        [{"marker":{"color":"#f49432"},"name":"Feminino","orientation":"h","text":{"dtype":"f8","bdata":"uB6F61G4TkDhehSuRwFPQGZmZmZmdlBAcT0K16PQTECPwvUoXP9QQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"uB6F61G4TkDhehSuRwFPQGZmZmZmdlBAcT0K16PQTECPwvUoXP9QQA=="},"y":["CURSO A DISTÂNCIA","INTEGRAL","MATUTINO","NOTURNO","VESPERTINO"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Masculino","orientation":"h","text":{"dtype":"f8","bdata":"SOF6FK5HQ0AfhetRuP5CQDMzMzMzE0FAj8L1KFwvRUDhehSuRwFAQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"SOF6FK5HQ0AfhetRuP5CQDMzMzMzE0FAj8L1KFwvRUDhehSuRwFAQA=="},"y":["CURSO A DISTÂNCIA","INTEGRAL","MATUTINO","NOTURNO","VESPERTINO"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{ ...

# %% [markdown]
# % por Turno e Tipo da Bolsa

# %%
df_turno_tipo = (pd.crosstab(prouni_2020['NOME_TURNO_CURSO_BOLSA'], prouni_2020['TIPO_BOLSA'], normalize='index') * 100).round(2)
df_turno_tipo = df_turno_tipo.reset_index()
df_turno_tipo
# Out:
# TIPO_BOLSA NOME_TURNO_CURSO_BOLSA  INTEGRAL  PARCIAL
# 0               CURSO A DISTÂNCIA     93.77     6.23
# 1                        INTEGRAL     74.38    25.62
# 2                        MATUTINO     73.54    26.46
# 3                         NOTURNO     70.24    29.76
# 4                      VESPERTINO     62.35    37.65

# %%
fig_turno_tipo = go.Figure()

fig_turno_tipo.add_trace(go.Bar(x = df_turno_tipo['INTEGRAL'], y = df_turno_tipo['NOME_TURNO_CURSO_BOLSA'], name = 'Integral', marker_color = '#f49432', orientation = 'h',
                              text=df_turno_tipo['INTEGRAL'], textposition='outside'))

fig_turno_tipo.add_trace(go.Bar(x = df_turno_tipo['PARCIAL'], y = df_turno_tipo['NOME_TURNO_CURSO_BOLSA'], name = 'Parcial', marker_color = '#296073', orientation = 'h',
                              text=df_turno_tipo['PARCIAL'], textposition='inside'))

fig_turno_tipo.update_layout(
    title = '<b> % Concessão por Turno e Tipo da Bolsa </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    font_size = 13,
    barmode = 'stack',
    template = 'simple_white',
    height = 450,
    width = 1000
)

fig_turno_tipo.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="dbbc63ac-083a-459e-af0d-640c33032d8a" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dbbc63ac-083a-459e-af0d-640c33032d8a")) {                    Plotly.newPlot(                        "dbbc63ac-083a-459e-af0d-640c33032d8a",                        [{"marker":{"color":"#f49432"},"name":"Integral","orientation":"h","text":{"dtype":"f8","bdata":"4XoUrkdxV0C4HoXrUZhSQMP1KFyPYlJAj8L1KFyPUUDNzMzMzCxPQA=="},"textposition":"outside","x":{"dtype":"f8","bdata":"4XoUrkdxV0C4HoXrUZhSQMP1KFyPYlJAj8L1KFyPUUDNzMzMzCxPQA=="},"y":["CURSO A DISTÂNCIA","INTEGRAL","MATUTINO","NOTURNO","VESPERTINO"],"type":"bar"},{"marker":{"color":"#296073"},"name":"Parcial","orientation":"h","text":{"dtype":"f8","bdata":"7FG4HoXrGEAfhetRuJ45QPYoXI\u002fCdTpAw\u002fUoXI\u002fCPUAzMzMzM9NCQA=="},"textposition":"inside","x":{"dtype":"f8","bdata":"7FG4HoXrGEAfhetRuJ45QPYoXI\u002fCdTpAw\u002fUoXI\u002fCPUAzMzMzM9NCQA=="},"y":["CURSO A DISTÂNCIA","INTEGRAL","MATUTINO","NOTURNO","VESPERTINO"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogra ...

# %% [markdown]
# ### Localidade

# %% [markdown]
# Região

# %%
regiao_qtd = prouni_2020['REGIAO_BENEFICIARIO'].value_counts()
regiao_percent = (regiao_qtd / regiao_qtd.sum() * 100).round(2)

df_regiao = pd.DataFrame({
    'QTD': regiao_qtd,
    '%': regiao_percent
})
df_regiao = df_regiao.reset_index()
df_regiao
# Out:
#   REGIAO_BENEFICIARIO    QTD      %
# 0             SUDESTE  71626  42.95
# 1            NORDESTE  39241  23.53
# 2                 SUL  26368  15.81
# 3               NORTE  16295   9.77
# 4        CENTRO-OESTE  13253   7.95

# %%
fig_regiao = go.Figure()
fig_regiao.add_trace(go.Bar(x = df_regiao['REGIAO_BENEFICIARIO'], y = df_regiao['QTD'], name = 'Região', marker_color = '#296073', text = df_regiao['QTD'],
                            texttemplate = '%{y:.0f} <br> (%{customdata:.2f}%)', customdata = df_regiao['%']))  # formatando rótulo com QTD e % e pulando linha entre eles

fig_regiao.update_layout(
    title = '<b> Concessão por Região </b> <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white',
    height = 450,
    width = 800
)

fig_regiao.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="83ea990a-f9ad-4573-b289-d826cf706cdb" class="plotly-graph-div" style="height:450px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("83ea990a-f9ad-4573-b289-d826cf706cdb")) {                    Plotly.newPlot(                        "83ea990a-f9ad-4573-b289-d826cf706cdb",                        [{"customdata":{"dtype":"f8","bdata":"mpmZmZl5RUBI4XoUroc3QB+F61G4ni9ACtejcD2KI0DNzMzMzMwfQA=="},"marker":{"color":"#296073"},"name":"Região","text":{"dtype":"f8","bdata":"AAAAAKB88UAAAAAAICnjQAAAAAAAwNlAAAAAAIDTz0AAAAAAgOLJQA=="},"texttemplate":"%{y:.0f} \u003cbr\u003e (%{customdata:.2f}%)","x":["SUDESTE","NORDESTE","SUL","NORTE","CENTRO-OESTE"],"y":{"dtype":"i4","bdata":"yhcBAEmZAAAAZwAApz8AAMUzAAA="},"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outli ...

# %% [markdown]
# UF

# %%
uf_qtd = prouni_2020['UF_BENEFICIARIO'].value_counts()
uf_percent = (uf_qtd / uf_qtd.sum() * 100).round(2)

df_uf = pd.DataFrame({
    'QTD': uf_qtd,
    '%': uf_percent
})
df_uf = df_uf.reset_index()
df_uf
# Out:
#    UF_BENEFICIARIO    QTD      %
# 0               SP  40370  24.21
# 1               MG  18933  11.35
# 2               RS  11478   6.88
# 3               BA  10250   6.15
# 4               PR   9916   5.95
# 5               RJ   8485   5.09
# 6               CE   6963   4.17
# 7               PE   6707   4.02
# 8               GO   6094   3.65
# 9               MA   6069   3.64
# 10              PA   5940   3.56
# 11              SC   4974   2.98
# 12              ES   3838   2.30
# 13              DF   3696   2.22
# 14              AM   3530   2.12
# 15              PB   2763   1.66
# 16              RO   2752   1.65
# 17              PI   2005   1.20
# 18              MT   1852   1.11
# 19              RN   1810   1.09
# 20              MS   1611   0.97
# 21              TO   1462   0.88
# 22              AL   1387   0.83
# 23              AC   1379   0.83
# 24              SE   1287   0.77
# 25              AP    811   0.49
# 26              RR    421   0.25

# %% [markdown]
# Top 10

# %%
top10_uf = df_uf.head(10)

fig_top10_uf = px.bar(top10_uf, x = 'QTD', y = 'UF_BENEFICIARIO',
                  title = '<b> Concessão por UF </b>- Top 10 <br> <sup> Ano: 2020 </sup>',
                  color_discrete_sequence = px.colors.qualitative.T10, height = 450, width = 1000,
                  template = 'simple_white',
                  text = top10_uf['QTD'],
                  category_orders={'UF_BENEFICIARIO': top10_uf['UF_BENEFICIARIO'].tolist()})

fig_top10_uf.update_layout(
    title_font_size = 15
)
fig_top10_uf.update_xaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_top10_uf.update_yaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_top10_uf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="47b502c0-9c33-411c-befc-48378403021e" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("47b502c0-9c33-411c-befc-48378403021e")) {                    Plotly.newPlot(                        "47b502c0-9c33-411c-befc-48378403021e",                        [{"hovertemplate":"QTD=%{text}\u003cbr\u003eUF_BENEFICIARIO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#4C78A8","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAEC240AAAAAAQH3SQAAAAAAAa8ZAAAAAAAAFxEAAAAAAAF7DQAAAAACAksBAAAAAAAAzu0AAAAAAADO6QAAAAAAAzrdAAAAAAAC1t0A="},"textposition":"auto","x":{"dtype":"i4","bdata":"sp0AAPVJAADWLAAACigAALwmAAAlIQAAMxsAADMaAADOFwAAtRcAAA=="},"xaxis":"x","y":["SP","MG","RS","BA","PR","RJ","CE","PE","GO","MA"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":1,"tick ...

# %% [markdown]
# Todas as UF

# %%
fig_uf = go.Figure()
fig_uf.add_trace(go.Bar(x = df_uf['UF_BENEFICIARIO'], y = df_uf['QTD'], name = 'UF', marker_color = '#296073', customdata = df_uf['%'], textposition = 'outside',
                            texttemplate='%{customdata:.1f}%'))  # formatando rótulo com o %

fig_uf.update_layout(
    title = '<b> Concessão por Região </b>- % de Distribuição por UF <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white',
    height = 600,
    width = 1300,
)
fig_uf.update_traces(
    textfont_size = 16
)
fig_uf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="97129652-3d3c-44cd-97b4-eeee92da789f" class="plotly-graph-div" style="height:600px; width:1300px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("97129652-3d3c-44cd-97b4-eeee92da789f")) {                    Plotly.newPlot(                        "97129652-3d3c-44cd-97b4-eeee92da789f",                        [{"customdata":{"dtype":"f8","bdata":"9ihcj8I1OEAzMzMzM7MmQIXrUbgehRtAmpmZmZmZGEDNzMzMzMwXQFyPwvUoXBRArkfhehSuEEAUrkfhehQQQDMzMzMzMw1AH4XrUbgeDUB7FK5H4XoMQNejcD0K1wdAZmZmZmZmAkDD9Shcj8IBQPYoXI\u002fC9QBAj8L1KFyP+j9mZmZmZmb6PzMzMzMzM\u002fM\u002fw\u002fUoXI\u002fC8T9xPQrXo3DxPwrXo3A9Cu8\u002fKVyPwvUo7D+PwvUoXI\u002fqP4\u002fC9Shcj+o\u002fpHA9Ctej6D9cj8L1KFzfPwAAAAAAANA\u002f"},"marker":{"color":"#296073"},"name":"UF","textposition":"outside","texttemplate":"%{customdata:.1f}%","x":["SP","MG","RS","BA","PR","RJ","CE","PE","GO","MA","PA","SC","ES","DF","AM","PB","RO","PI","MT","RN","MS","TO","AL","AC","SE","AP","RR"],"y":{"dtype":"i4","bdata":"sp0AAPVJAADWLAAACigAALwmAAAlIQAAMxsAADMaAADOFwAAtRcAADQXAABuEwAA\u002fg4AAHAOAADKDQAAywoAAMAKAADVBwAAPAcAABIHAABLBgAAtgUAAGsFAABjBQAABwUAACsDAAClAQAA"},"type":"bar","textfont":{"size":16}}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde7 ...

# %% [markdown]
# ## TOP 10 dos Cursos

# %% [markdown]
# ### Todas as Modalidades

# %%
curso_qtd = prouni_2020['NOME_CURSO_BOLSA'].value_counts()
curso_percent = (curso_qtd / curso_qtd.sum() * 100).round(2)

df_curso = pd.DataFrame({
    'QTD': curso_qtd,
    '%': curso_percent
})
df_curso.head(10)
# Out:
#                               QTD     %
# NOME_CURSO_BOLSA
# DIREITO                     15082  9.04
# ADMINISTRAÇÃO               14897  8.93
# PEDAGOGIA                   13660  8.19
# ENFERMAGEM                   9232  5.54
# CIÊNCIAS CONTÁBEIS           8570  5.14
# EDUCAÇÃO FÍSICA              7600  4.56
# PSICOLOGIA                   7447  4.47
# GESTÃO DE RECURSOS HUMANOS   5575  3.34
# FISIOTERAPIA                 4581  2.75
# FARMÁCIA                     4055  2.43

# %%
curso = prouni_2020['NOME_CURSO_BOLSA'].value_counts().head(10).reset_index()
curso.columns = ['CURSO', 'QTD']

fig_curso = px.bar(curso, x = 'QTD', y = 'CURSO',
                  title = '<b> Concessão por Curso </b> (Top 10 - Todas as Modalidades) <br> <sup> Ano: 2020 </sup>',
                  color_discrete_sequence = px.colors.qualitative.T10, height = 450, width = 1000,
                  template = 'simple_white',
                  text = curso['QTD'],
                  category_orders = {'CURSO': curso['CURSO'].tolist()})

fig_curso.update_layout(
    title_font_size = 15
)
fig_curso.update_xaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso.update_yaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="49c344d7-f164-4d2c-b7de-d70044c82b95" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("49c344d7-f164-4d2c-b7de-d70044c82b95")) {                    Plotly.newPlot(                        "49c344d7-f164-4d2c-b7de-d70044c82b95",                        [{"hovertemplate":"QTD=%{text}\u003cbr\u003eCURSO=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#4C78A8","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAB1zUAAAAAAgBjNQAAAAAAArspAAAAAAAAIwkAAAAAAAL3AQAAAAAAAsL1AAAAAAAAXvUAAAAAAAMe1QAAAAAAA5bFAAAAAAACur0A="},"textposition":"auto","x":{"dtype":"i2","bdata":"6joxOlw1ECR6IbAdFx3HFeUR1w8="},"xaxis":"x","y":["DIREITO","ADMINISTRAÇÃO","PEDAGOGIA","ENFERMAGEM","CIÊNCIAS CONTÁBEIS","EDUCAÇÃO FÍSICA","PSICOLOGIA","GESTÃO DE RECURSOS HUMANOS","FISIOTERAPIA","FARMÁCIA"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"typ ...

# %%
# Identificando os 10 cursos com mais bolsas concedidas e os abrindo por modalidade

top_10_cursos = prouni_2020['NOME_CURSO_BOLSA'].value_counts().head(10).index

cursos_top_10 = prouni_2020[prouni_2020['NOME_CURSO_BOLSA'].isin(top_10_cursos)]

curso_mod = cursos_top_10.pivot_table(index='NOME_CURSO_BOLSA',
                                            columns='MODALIDADE_ENSINO_BOLSA',
                                            aggfunc='size',
                                            fill_value=0)

curso_mod = curso_mod.reset_index()

curso_mod['Total'] = curso_mod['EAD'] + curso_mod['PRESENCIAL']

curso_mod = curso_mod.sort_values(by='Total', ascending=False)
curso_mod
# Out:
# MODALIDADE_ENSINO_BOLSA            NOME_CURSO_BOLSA   EAD  PRESENCIAL  Total
# 2                                           DIREITO     0       15082  15082
# 0                                     ADMINISTRAÇÃO  7126        7771  14897
# 8                                         PEDAGOGIA  9760        3900  13660
# 4                                        ENFERMAGEM  1536        7696   9232
# 1                                CIÊNCIAS CONTÁBEIS  3984        4586   8570
# 3                                   EDUCAÇÃO FÍSICA  3713        3887   7600
# 9                                        PSICOLOGIA     0        7447   7447
# 7                        GESTÃO DE RECURSOS HUMANOS  3437        2138   5575
# 6                                      FISIOTERAPIA   241        4340   4581
# 5                                          FARMÁCIA   273        3782   4055

# %%
# Top 10 abrindo entre Presencial e EAD

fig_cursos = go.Figure()
fig_cursos.add_trace(go.Bar(x = curso_mod['EAD'], y = curso_mod['NOME_CURSO_BOLSA'], name = 'EAD', marker_color = '#f49432', orientation = 'h'))
fig_cursos.add_trace(go.Bar(x = curso_mod['PRESENCIAL'], y = curso_mod['NOME_CURSO_BOLSA'], name = 'PRESENCIAL', marker_color = '#296073', orientation = 'h'))

fig_cursos.update_layout(
    title = '<b> Concessão por Curso </b> (Top 10 - Aberto por Modalidade) <br> <sup> Ano: 2020 </sup>',
    title_font_size = 15,
    barmode = 'group',
    template = 'simple_white'
)

fig_cursos.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="962d48b7-2a0f-4ee5-a0cb-37e344f1842a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("962d48b7-2a0f-4ee5-a0cb-37e344f1842a")) {                    Plotly.newPlot(                        "962d48b7-2a0f-4ee5-a0cb-37e344f1842a",                        [{"marker":{"color":"#f49432"},"name":"EAD","orientation":"h","x":{"dtype":"i2","bdata":"AADWGyAmAAaQD4EOAABtDfEAEQE="},"y":["DIREITO","ADMINISTRAÇÃO","PEDAGOGIA","ENFERMAGEM","CIÊNCIAS CONTÁBEIS","EDUCAÇÃO FÍSICA","PSICOLOGIA","GESTÃO DE RECURSOS HUMANOS","FISIOTERAPIA","FARMÁCIA"],"type":"bar"},{"marker":{"color":"#296073"},"name":"PRESENCIAL","orientation":"h","x":{"dtype":"i2","bdata":"6jpbHjwPEB7qES8PFx1aCPQQxg4="},"y":["DIREITO","ADMINISTRAÇÃO","PEDAGOGIA","ENFERMAGEM","CIÊNCIAS CONTÁBEIS","EDUCAÇÃO FÍSICA","PSICOLOGIA","GESTÃO DE RECURSOS HUMANOS","FISIOTERAPIA","FARMÁCIA"],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"mesh3d"}],"parcoords":[{"line": ...

# %% [markdown]
# ### Modalidade Presencial

# %%
prouni_2020_presencial = prouni_2020[prouni_2020['MODALIDADE_ENSINO_BOLSA'] == 'PRESENCIAL']
prouni_2020_ead = prouni_2020[prouni_2020['MODALIDADE_ENSINO_BOLSA'] == 'EAD']

# %%
curso_qtd_presencial = prouni_2020_presencial['NOME_CURSO_BOLSA'].value_counts()
curso_percent_presencial = (curso_qtd_presencial / curso_qtd_presencial.sum() * 100).round(2)

df_curso_presencial = pd.DataFrame({
    'QTD PRESENCIAL': curso_qtd_presencial,
    '% PRESENCIAL': curso_percent_presencial
})
df_curso_presencial.head(10)
# Out:
#                     QTD PRESENCIAL  % PRESENCIAL
# NOME_CURSO_BOLSA
# DIREITO                      15082         13.35
# ADMINISTRAÇÃO                 7771          6.88
# ENFERMAGEM                    7696          6.81
# PSICOLOGIA                    7447          6.59
# CIÊNCIAS CONTÁBEIS            4586          4.06
# FISIOTERAPIA                  4340          3.84
# PEDAGOGIA                     3900          3.45
# EDUCAÇÃO FÍSICA               3887          3.44
# ODONTOLOGIA                   3816          3.38
# FARMÁCIA                      3782          3.35

# %%
curso_presencial = prouni_2020_presencial['NOME_CURSO_BOLSA'].value_counts().head(10).reset_index()
curso_presencial.columns = ['CURSO Presencial', 'QTD Presencial']

fig_curso_presencial = px.bar(curso_presencial, x = 'QTD Presencial', y = 'CURSO Presencial',
                  title = '<b> Concessão por Curso </b> - Top 10  Modalidade Presencial <br> <sup> Ano: 2020 </sup>',
                  template = 'simple_white',
                  text = curso_presencial['QTD Presencial'],
                  category_orders = {'CURSO Presencial': curso_presencial['CURSO Presencial'].tolist()})

fig_curso_presencial.update_layout(title_font_size = 15, height = 450, width = 1000)

fig_curso_presencial.update_traces(marker_color = '#296073')

fig_curso_presencial.update_xaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso_presencial.update_yaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso_presencial.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3d414b28-6513-4acb-ace6-f31f902cd1e7" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3d414b28-6513-4acb-ace6-f31f902cd1e7")) {                    Plotly.newPlot(                        "3d414b28-6513-4acb-ace6-f31f902cd1e7",                        [{"hovertemplate":"QTD Presencial=%{text}\u003cbr\u003eCURSO Presencial=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#296073","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAB1zUAAAAAAAFu+QAAAAAAAEL5AAAAAAAAXvUAAAAAAAOqxQAAAAAAA9LBAAAAAAAB4rkAAAAAAAF6uQAAAAAAA0K1AAAAAAACMrUA="},"textposition":"auto","x":{"dtype":"i2","bdata":"6jpbHhAeFx3qEfQQPA8vD+gOxg4="},"xaxis":"x","y":["DIREITO","ADMINISTRAÇÃO","ENFERMAGEM","PSICOLOGIA","CIÊNCIAS CONTÁBEIS","FISIOTERAPIA","PEDAGOGIA","EDUCAÇÃO FÍSICA","ODONTOLOGIA","FARMÁCIA"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside ...

# %% [markdown]
# ### Modalidade EAD

# %%
curso_qtd_ead = prouni_2020_ead['NOME_CURSO_BOLSA'].value_counts()
curso_percent_ead = (curso_qtd_ead / curso_qtd_ead.sum() * 100).round(2)

df_curso_ead = pd.DataFrame({
    'QTD EAD': curso_qtd_ead,
    '% EAD': curso_percent_ead
})
df_curso_ead.head(10)
# Out:
#                                        QTD EAD  % EAD
# NOME_CURSO_BOLSA
# PEDAGOGIA                                 9760  18.14
# ADMINISTRAÇÃO                             7126  13.24
# CIÊNCIAS CONTÁBEIS                        3984   7.40
# EDUCAÇÃO FÍSICA                           3713   6.90
# GESTÃO DE RECURSOS HUMANOS                3437   6.39
# SERVIÇO SOCIAL                            1795   3.34
# ANÁLISE E DESENVOLVIMENTO DE SISTEMAS     1622   3.01
# ENFERMAGEM                                1536   2.85
# LOGÍSTICA                                 1386   2.58
# PROCESSOS GERENCIAIS                      1265   2.35

# %%
curso_ead = prouni_2020_ead['NOME_CURSO_BOLSA'].value_counts().head(10).reset_index()
curso_ead.columns = ['CURSO EAD', 'QTD EAD']

fig_curso_ead = px.bar(curso_ead, x = 'QTD EAD', y = 'CURSO EAD',
                  title = '<b> Concessão por Curso </b> - Top 10  Modalidade EAD <br> <sup> Ano: 2020 </sup>',
                  template = 'simple_white',
                  text = curso_ead['QTD EAD'],
                  category_orders = {'CURSO EAD': curso_ead['CURSO EAD'].tolist()})

fig_curso_ead.update_layout(title_font_size=15, height = 450, width = 1000)

fig_curso_ead.update_traces(marker_color = '#f49432')

fig_curso_ead.update_xaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso_ead.update_yaxes(title = '', ticks = 'outside', tickfont_size= 13)
fig_curso_ead.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="3863c744-edb3-4b88-b1e0-763ff3304e8c" class="plotly-graph-div" style="height:450px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3863c744-edb3-4b88-b1e0-763ff3304e8c")) {                    Plotly.newPlot(                        "3863c744-edb3-4b88-b1e0-763ff3304e8c",                        [{"hovertemplate":"QTD EAD=%{text}\u003cbr\u003eCURSO EAD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#f49432","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":{"dtype":"f8","bdata":"AAAAAAAQw0AAAAAAANa7QAAAAAAAIK9AAAAAAAACrUAAAAAAANqqQAAAAAAADJxAAAAAAABYmUAAAAAAAACYQAAAAAAAqJVAAAAAAADEk0A="},"textposition":"auto","x":{"dtype":"i2","bdata":"ICbWG5APgQ5tDQMHVgYABmoF8QQ="},"xaxis":"x","y":["PEDAGOGIA","ADMINISTRAÇÃO","CIÊNCIAS CONTÁBEIS","EDUCAÇÃO FÍSICA","GESTÃO DE RECURSOS HUMANOS","SERVIÇO SOCIAL","ANÁLISE E DESENVOLVIMENTO DE SISTEMAS","ENFERMAGEM","LOGÍSTICA","PROCESSOS GERENCIAIS"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2d"}],"histogram":[{"marker":{"line":{"color":"white","width":0.6}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":1, ...
